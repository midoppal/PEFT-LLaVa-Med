# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/microsoft/LLaVA-Med.git
# Out:
# Cloning into 'LLaVA-Med'...
# remote: Enumerating objects: 451, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 451 (delta 53), reused 51 (delta 49), pack-reused 345 (from 2)
# Receiving objects: 100% (451/451), 77.08 MiB | 16.66 MiB/s, done.
# Resolving deltas: 100% (135/135), done.
# Filtering content: 100% (10/10), 813.63 MiB | 37.22 MiB/s, done.

# %%
# %cd LLaVA-Med
# Out:
# /content/LLaVA-Med

# %%
# Install pip in editable mode with PEP 660 compatibility
# !pip install --upgrade pip setuptools wheel

# Install the repo and its dependencies
# !pip install -e .

# !pip install numpy==1.26.4
# !pip install torch==2.1.2 torchvision==0.16.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.38.1
# !pip uninstall -y bitsandbytes  # remove it completely
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (80.9.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (0.45.1)
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 185.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.1.2
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.1.2%2Bcu118-cp311-cp311-linux_x86_64.whl (2325.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 23.0 MB/s eta 0:00:00
# Collecting torchvision==0.16.2
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.16.2%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 165.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2) (4.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.1.2) (2025.3.2)
# Collecting triton==2.1.0 (from torch==2.1.2)
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 173.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.16.2) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.16.2) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.16.2) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.1.2) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.2) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.16.2) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.1.2) (1.3.0)
# Installing collected packages: triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchvision]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.1.2+cu118 which is incompatible.
# Successfully installed torch-2.1.2+cu118 torchvision-0.16.2+cu118 triton-2.1.0
# Collecting transformers==4.38.1
#   Using cached transformers-4.38.1-py3-none-any.whl.metadata (131 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (0.32.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.38.1)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.38.1) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.1) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.1) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.1) (1.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.38.1) (2025.4.26)
# Downloading transformers-4.38.1-py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 109.3 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 59.4 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.38.1 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.38.1
# WARNING: Skipping bitsandbytes as it is not installed.

# %%
# !mkdir -p checkpoints
# !huggingface-cli download microsoft/llava-med-v1.5-mistral-7b --local-dir checkpoints/llava-med-v1.5-mistral-7b --local-dir-use-symlinks False
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/commands/download.py:139: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]Downloading 'model-00003-of-00004.safetensors' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/DaGOU-KRMVrY0aYktrsE34tL0Bs=.12b18ecdf8924d5fe28ada797fe6697fa60e62cba630759fbeb52975b261c4e2.incomplete'
# Downloading 'model-00001-of-00004.safetensors' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/IO4xwqmZYzFmxznkwkiNSBwO1H0=.ef2190dc6c2a940e60f03f5fdb4dddb2320eb87801aeca5c40b0a28ce8aa420e.incomplete'
# Downloading 'generation_config.json' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.c533f934c6359393a56a3ea067a0df118c14797e.incomplete'
# Downloading 'model-00002-of-00004.safetensors' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/t9msAuTjAZjuQnmzGOwTjiptvIU=.2b229607fecd98b8111320178e5bf3e2c527b05a942c85d65b5b507c76c1ed00.incomplete'
# Downloading 'README.md' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.0a9ac39d9b74ce19b755c242138c2acc76424a8b.incomplete'
# Downloading '.gitattributes' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# Downloading 'model-00004-of-00004.safetensors' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/-dFtyT7kcgbTHt1cy9JKqruJCR4=.1d2063fcd429d3f0f0a8a091b0522f0e02f2d85fe0e5b0eeb4ae168183a603bc.incomplete'
#
# model-00001-of-00004.safetensors:   0% 0.00/4.94G [00:00<?, ?B/s]
#
# model-00004-of-00004.safetensors:   0% 0.00/262M [00:00<?, ?B/s]
#
#
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]Downloading 'config.json' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.67f64739df128b33a83cf4bee2371d28de863d3c.incomplete'
#
#
#
#
# model-00003-of-00004.safetensors:   0% 0.00/4.93G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 21.0M/4.94G [00:00<00:31, 159MB/s]
#
#
# model-00002-of-00004.safetensors:   0% 21.0M/5.00G [00:00<00:33, 147MB/s]
#
# model-00004-of-00004.safetensors:   8% 21.0M/262M [00:00<00:01, 133MB/s]
#
#
#
# model-00003-of-00004.safetensors:   0% 21.0M/4.93G [00:00<00:34, 140MB/s]
#
#
#
#
# README.md: 100% 4.50k/4.50k [00:00<00:00, 16.6MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/README.md
#
#
#
#
#
# generation_config.json: 100% 111/111 [00:00<00:00, 946kB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/generation_config.json
#
# model-00001-of-00004.safetensors:   1% 41.9M/4.94G [00:00<00:29, 166MB/s]
#
#
# model-00002-of-00004.safetensors:   1% 41.9M/5.00G [00:00<00:30, 164MB/s]
#
# model-00004-of-00004.safetensors:  16% 41.9M/262M [00:00<00:01, 159MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1% 52.4M/4.93G [00:00<00:24, 199MB/s]
#
#
#
#
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 8.84MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/.gitattributes
#
#
#
#
#
# config.json: 100% 1.41k/1.41k [00:00<00:00, 17.4MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/config.json
# Fetching 12 files:   8% 1/12 [00:00<00:06,  1.60it/s]
# model-00001-of-00004.safetensors:   1% 73.4M/4.94G [00:00<00:24, 202MB/s]
#
#
# model-00002-of-00004.safetensors:   1% 73.4M/5.00G [00:00<00:24, 199MB/s]
#
# model-00004-of-00004.safetensors:  28% 73.4M/262M [00:00<00:00, 191MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2% 83.9M/4.93G [00:00<00:22, 213MB/s]Downloading 'model.safetensors.index.json' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.55947b5538de3bfdd41f73730d8dba165e080e94.incomplete'
# Downloading 'special_tokens_map.json' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.14761dcf1466dc232bd41de9c21d4c617b15755e.incomplete'
#
# model-00001-of-00004.safetensors:   2% 105M/4.94G [00:00<00:22, 219MB/s]
#
#
# model-00002-of-00004.safetensors:   2% 105M/5.00G [00:00<00:23, 209MB/s]
#
# model-00004-of-00004.safetensors:  40% 105M/262M [00:00<00:00, 209MB/s] Downloading 'tokenizer.model' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/7iVfz3cUOMr-hyjiqqRDHEwVBAM=.dadfd56d766715c61d2ef780a525ab43b8e6da4de6865bda3d95fdef5e134055.incomplete'
# Downloading 'tokenizer_config.json' to 'checkpoints/llava-med-v1.5-mistral-7b/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.23dcf70e8cfc9b16310b6ff3dc98fdbc5adc11f8.incomplete'
#
#
#
#
#
# tokenizer.model:   0% 0.00/493k [00:00<?, ?B/s]
#
#
#
# tokenizer.model: 100% 493k/493k [00:00<00:00, 34.6MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/tokenizer.model
#
# model-00001-of-00004.safetensors:   3% 136M/4.94G [00:00<00:21, 219MB/s]
#
#
# model-00002-of-00004.safetensors:   3% 136M/5.00G [00:00<00:22, 214MB/s]
#
# model-00004-of-00004.safetensors:  52% 136M/262M [00:00<00:00, 211MB/s]
#
#
#
#
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 2.75MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/special_tokens_map.json
#
#
#
#
# model-00003-of-00004.safetensors:   3% 147M/4.93G [00:00<00:21, 222MB/s]
#
#
#
#
# model.safetensors.index.json: 100% 73.2k/73.2k [00:00<00:00, 33.3MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/model.safetensors.index.json
#
# model-00001-of-00004.safetensors:   3% 168M/4.94G [00:00<00:21, 226MB/s]
#
#
#
#
# tokenizer_config.json: 100% 1.46k/1.46k [00:00<00:00, 10.4MB/s]
#
#
#
# model-00002-of-00004.safetensors:   3% 168M/5.00G [00:00<00:23, 209MB/s]Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/tokenizer_config.json
#
#
# model-00004-of-00004.safetensors:  64% 168M/262M [00:00<00:00, 211MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 178M/4.93G [00:00<00:20, 226MB/s]
# model-00001-of-00004.safetensors:   4% 199M/4.94G [00:00<00:20, 229MB/s]
#
# model-00004-of-00004.safetensors:  76% 199M/262M [00:00<00:00, 221MB/s]
#
#
# model-00002-of-00004.safetensors:   4% 199M/5.00G [00:00<00:22, 212MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4% 210M/4.93G [00:00<00:20, 230MB/s]
# model-00001-of-00004.safetensors:   5% 231M/4.94G [00:01<00:19, 238MB/s]
#
# model-00004-of-00004.safetensors:  88% 231M/262M [00:01<00:00, 229MB/s]
#
#
# model-00002-of-00004.safetensors:   5% 231M/5.00G [00:01<00:21, 220MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5% 241M/4.93G [00:01<00:19, 234MB/s]
# model-00001-of-00004.safetensors:   5% 262M/4.94G [00:01<00:19, 242MB/s]
#
# model-00004-of-00004.safetensors: 100% 262M/262M [00:01<00:00, 229MB/s]
#
#
#
# model-00004-of-00004.safetensors: 100% 262M/262M [00:01<00:00, 211MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/model-00004-of-00004.safetensors
#
#
#
# model-00002-of-00004.safetensors:   5% 262M/5.00G [00:01<00:21, 221MB/s]
# model-00001-of-00004.safetensors:   6% 294M/4.94G [00:01<00:19, 243MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6% 304M/4.93G [00:01<00:18, 249MB/s]
#
#
# model-00002-of-00004.safetensors:   6% 304M/5.00G [00:01<00:18, 259MB/s]
# model-00001-of-00004.safetensors:   7% 325M/4.94G [00:01<00:23, 194MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7% 336M/4.93G [00:01<00:21, 213MB/s]
#
#
# model-00002-of-00004.safetensors:   7% 336M/5.00G [00:01<00:26, 175MB/s]
# model-00001-of-00004.safetensors:   7% 346M/4.94G [00:01<00:26, 171MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7% 367M/4.93G [00:01<00:26, 172MB/s]
# model-00001-of-00004.safetensors:   7% 367M/4.94G [00:01<00:26, 171MB/s]
#
#
# model-00002-of-00004.safetensors:   7% 367M/5.00G [00:01<00:25, 185MB/s]
# model-00001-of-00004.safetensors:   8% 388M/4.94G [00:01<00:27, 165MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8% 409M/4.93G [00:02<00:25, 176MB/s]
# model-00001-of-00004.safetensors:   8% 409M/4.94G [00:02<00:30, 150MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9% 430M/4.93G [00:02<00:28, 161MB/s]
#
#
# model-00002-of-00004.safetensors:   8% 398M/5.00G [00:02<00:34, 132MB/s]
# model-00001-of-00004.safetensors:   9% 440M/4.94G [00:02<00:25, 174MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9% 451M/4.93G [00:02<00:28, 155MB/s]
# model-00001-of-00004.safetensors:   9% 461M/4.94G [00:02<00:27, 160MB/s]
#
#
# model-00002-of-00004.safetensors:   8% 419M/5.00G [00:02<00:37, 122MB/s]
# model-00001-of-00004.safetensors:  10% 482M/4.94G [00:02<00:28, 154MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 472M/4.93G [00:02<00:33, 133MB/s]
#
#
# model-00002-of-00004.safetensors:   9% 440M/5.00G [00:02<00:36, 127MB/s]
# model-00001-of-00004.safetensors:  10% 503M/4.94G [00:02<00:31, 142MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 493M/4.93G [00:02<00:34, 127MB/s]
#
#
# model-00002-of-00004.safetensors:   9% 461M/5.00G [00:02<00:36, 123MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10% 514M/4.93G [00:02<00:34, 127MB/s]
# model-00001-of-00004.safetensors:  11% 535M/4.94G [00:02<00:30, 147MB/s]
#
#
# model-00002-of-00004.safetensors:  10% 482M/5.00G [00:02<00:37, 122MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11% 535M/4.93G [00:03<00:32, 136MB/s]
# model-00001-of-00004.safetensors:  11% 556M/4.94G [00:03<00:30, 145MB/s]
# model-00001-of-00004.safetensors:  12% 577M/4.94G [00:03<00:33, 132MB/s]
#
#
# model-00002-of-00004.safetensors:  10% 503M/5.00G [00:03<00:47, 94.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11% 556M/4.93G [00:03<00:38, 114MB/s]
#
#
# model-00002-of-00004.safetensors:  10% 524M/5.00G [00:03<00:41, 108MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 577M/4.93G [00:03<00:34, 126MB/s]
# model-00001-of-00004.safetensors:  12% 598M/4.94G [00:03<00:32, 133MB/s]
# model-00001-of-00004.safetensors:  13% 619M/4.94G [00:03<00:30, 141MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12% 608M/4.93G [00:03<00:32, 134MB/s]
#
#
# model-00002-of-00004.safetensors:  11% 556M/5.00G [00:03<00:39, 113MB/s]
# model-00001-of-00004.safetensors:  13% 640M/4.94G [00:03<00:34, 124MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13% 629M/4.93G [00:03<00:31, 137MB/s]
#
#
# model-00002-of-00004.safetensors:  12% 577M/5.00G [00:03<00:35, 124MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13% 650M/4.93G [00:03<00:30, 142MB/s]
#
#
# model-00002-of-00004.safetensors:  12% 598M/5.00G [00:03<00:34, 126MB/s]
# model-00001-of-00004.safetensors:  13% 661M/4.94G [00:03<00:35, 121MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14% 682M/4.93G [00:04<00:26, 163MB/s]
# model-00001-of-00004.safetensors:  14% 682M/4.94G [00:04<00:34, 124MB/s]
#
#
# model-00002-of-00004.safetensors:  12% 619M/5.00G [00:04<00:36, 121MB/s]
# model-00001-of-00004.safetensors:  14% 703M/4.94G [00:04<00:32, 130MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14% 703M/4.93G [00:04<00:30, 140MB/s]
#
#
# model-00002-of-00004.safetensors:  13% 640M/5.00G [00:04<00:38, 114MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15% 724M/4.93G [00:04<00:29, 144MB/s]
#
#
# model-00002-of-00004.safetensors:  13% 661M/5.00G [00:04<00:34, 127MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15% 744M/4.93G [00:04<00:29, 143MB/s]
# model-00001-of-00004.safetensors:  15% 724M/4.94G [00:04<00:41, 103MB/s]
#
#
# model-00002-of-00004.safetensors:  14% 682M/5.00G [00:04<00:30, 143MB/s]
#
#
# model-00002-of-00004.safetensors:  14% 703M/5.00G [00:04<00:28, 151MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 765M/4.93G [00:04<00:31, 134MB/s]
# model-00001-of-00004.safetensors:  15% 744M/4.94G [00:04<00:45, 92.5MB/s]
#
#
# model-00002-of-00004.safetensors:  14% 724M/5.00G [00:04<00:29, 144MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 786M/4.93G [00:04<00:32, 127MB/s]
# model-00001-of-00004.safetensors:  15% 765M/4.94G [00:05<00:39, 107MB/s]
#
#
# model-00002-of-00004.safetensors:  15% 744M/5.00G [00:05<00:33, 127MB/s]
# model-00001-of-00004.safetensors:  16% 786M/4.94G [00:05<00:34, 121MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16% 807M/4.93G [00:05<00:33, 125MB/s]
#
#
# model-00002-of-00004.safetensors:  15% 765M/5.00G [00:05<00:31, 134MB/s]
# model-00001-of-00004.safetensors:  16% 807M/4.94G [00:05<00:34, 119MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17% 828M/4.93G [00:05<00:33, 122MB/s]
#
#
# model-00002-of-00004.safetensors:  16% 786M/5.00G [00:05<00:28, 148MB/s]
# model-00001-of-00004.safetensors:  17% 828M/4.94G [00:05<00:30, 134MB/s]
#
#
# model-00002-of-00004.safetensors:  16% 807M/5.00G [00:05<00:29, 143MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17% 849M/4.93G [00:05<00:37, 109MB/s]
# model-00001-of-00004.safetensors:  17% 849M/4.94G [00:05<00:33, 122MB/s]
#
#
# model-00002-of-00004.safetensors:  17% 828M/5.00G [00:05<00:29, 141MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18% 870M/4.93G [00:05<00:36, 111MB/s]
# model-00001-of-00004.safetensors:  18% 870M/4.94G [00:05<00:34, 120MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18% 891M/4.93G [00:05<00:33, 119MB/s]
#
#
# model-00002-of-00004.safetensors:  17% 849M/5.00G [00:05<00:34, 120MB/s]
# model-00001-of-00004.safetensors:  18% 891M/4.94G [00:05<00:29, 137MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 912M/4.93G [00:05<00:30, 130MB/s]
#
#
# model-00002-of-00004.safetensors:  17% 870M/5.00G [00:06<00:34, 120MB/s]
# model-00001-of-00004.safetensors:  18% 912M/4.94G [00:06<00:31, 127MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 933M/4.93G [00:06<00:30, 130MB/s]
#
#
# model-00002-of-00004.safetensors:  18% 891M/5.00G [00:06<00:34, 117MB/s]
# model-00001-of-00004.safetensors:  19% 933M/4.94G [00:06<00:33, 120MB/s]
#
#
#
# model-00003-of-00004.safetensors:  19% 954M/4.93G [00:06<00:31, 126MB/s]
#
#
# model-00002-of-00004.safetensors:  18% 912M/5.00G [00:06<00:34, 120MB/s]
# model-00001-of-00004.safetensors:  19% 954M/4.94G [00:06<00:31, 125MB/s]
#
#
#
# model-00003-of-00004.safetensors:  20% 975M/4.93G [00:06<00:30, 128MB/s]
#
#
# model-00002-of-00004.safetensors:  19% 933M/5.00G [00:06<00:30, 132MB/s]
# model-00001-of-00004.safetensors:  20% 975M/4.94G [00:06<00:31, 127MB/s]
#
#
#
# model-00003-of-00004.safetensors:  20% 996M/4.93G [00:06<00:33, 119MB/s]
#
#
# model-00002-of-00004.safetensors:  19% 954M/5.00G [00:06<00:31, 129MB/s]
# model-00001-of-00004.safetensors:  20% 996M/4.94G [00:06<00:33, 119MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.02G/4.93G [00:06<00:29, 132MB/s]
#
#
# model-00002-of-00004.safetensors:  20% 975M/5.00G [00:06<00:30, 131MB/s]
# model-00001-of-00004.safetensors:  21% 1.02G/4.94G [00:06<00:31, 125MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.04G/4.93G [00:06<00:30, 128MB/s]
#
#
# model-00002-of-00004.safetensors:  20% 996M/5.00G [00:07<00:31, 126MB/s]
#
#
#
# model-00003-of-00004.safetensors:  21% 1.06G/4.93G [00:07<00:28, 135MB/s]
# model-00001-of-00004.safetensors:  21% 1.04G/4.94G [00:07<00:33, 116MB/s]
#
#
#
# model-00003-of-00004.safetensors:  22% 1.08G/4.93G [00:07<00:25, 149MB/s]
#
#
# model-00002-of-00004.safetensors:  20% 1.02G/5.00G [00:07<00:33, 118MB/s]
#
#
#
# model-00003-of-00004.safetensors:  22% 1.10G/4.93G [00:07<00:24, 158MB/s]
# model-00001-of-00004.safetensors:  21% 1.06G/4.94G [00:07<00:35, 110MB/s]
#
#
#
# model-00003-of-00004.safetensors:  23% 1.12G/4.93G [00:07<00:25, 152MB/s]
#
#
# model-00002-of-00004.safetensors:  21% 1.04G/5.00G [00:07<00:38, 103MB/s]
# model-00001-of-00004.safetensors:  22% 1.08G/4.94G [00:07<00:34, 112MB/s]
#
#
#
# model-00003-of-00004.safetensors:  23% 1.14G/4.93G [00:07<00:25, 147MB/s]
#
#
# model-00002-of-00004.safetensors:  21% 1.06G/5.00G [00:07<00:37, 104MB/s]
# model-00001-of-00004.safetensors:  22% 1.10G/4.94G [00:07<00:32, 117MB/s]
#
#
#
# model-00003-of-00004.safetensors:  24% 1.16G/4.93G [00:07<00:28, 131MB/s]
#
#
# model-00002-of-00004.safetensors:  22% 1.08G/5.00G [00:07<00:38, 103MB/s]
#
#
#
# model-00003-of-00004.safetensors:  24% 1.18G/4.93G [00:07<00:26, 141MB/s]
#
#
# model-00002-of-00004.safetensors:  22% 1.10G/5.00G [00:08<00:34, 114MB/s]
# model-00001-of-00004.safetensors:  23% 1.12G/4.94G [00:08<00:44, 85.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  24% 1.21G/4.93G [00:08<00:26, 142MB/s]
#
#
# model-00002-of-00004.safetensors:  22% 1.12G/5.00G [00:08<00:31, 122MB/s]
#
#
#
# model-00003-of-00004.safetensors:  25% 1.23G/4.93G [00:08<00:25, 144MB/s]
# model-00001-of-00004.safetensors:  23% 1.14G/4.94G [00:08<00:39, 96.4MB/s]
#
#
# model-00002-of-00004.safetensors:  23% 1.14G/5.00G [00:08<00:30, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  25% 1.25G/4.93G [00:08<00:24, 148MB/s]
# model-00001-of-00004.safetensors:  24% 1.16G/4.94G [00:08<00:34, 108MB/s]
#
#
# model-00002-of-00004.safetensors:  23% 1.16G/5.00G [00:08<00:28, 136MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.27G/4.93G [00:08<00:26, 138MB/s]
# model-00001-of-00004.safetensors:  24% 1.18G/4.94G [00:08<00:33, 112MB/s]
#
#
# model-00002-of-00004.safetensors:  24% 1.18G/5.00G [00:08<00:29, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  26% 1.29G/4.93G [00:08<00:26, 135MB/s]
# model-00001-of-00004.safetensors:  24% 1.21G/4.94G [00:08<00:32, 116MB/s]
#
#
# model-00002-of-00004.safetensors:  24% 1.21G/5.00G [00:08<00:28, 131MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.31G/4.93G [00:08<00:27, 132MB/s]
# model-00001-of-00004.safetensors:  25% 1.23G/4.94G [00:08<00:32, 116MB/s]
#
#
# model-00002-of-00004.safetensors:  25% 1.23G/5.00G [00:08<00:28, 132MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.33G/4.93G [00:09<00:27, 131MB/s]
# model-00001-of-00004.safetensors:  25% 1.25G/4.94G [00:09<00:29, 124MB/s]
#
#
# model-00002-of-00004.safetensors:  25% 1.25G/5.00G [00:09<00:27, 137MB/s]
#
#
#
# model-00003-of-00004.safetensors:  27% 1.35G/4.93G [00:09<00:26, 134MB/s]
# model-00001-of-00004.safetensors:  26% 1.27G/4.94G [00:09<00:29, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  25% 1.27G/5.00G [00:09<00:28, 133MB/s]
#
#
#
# model-00003-of-00004.safetensors:  28% 1.37G/4.93G [00:09<00:25, 139MB/s]
# model-00001-of-00004.safetensors:  26% 1.29G/4.94G [00:09<00:28, 127MB/s]
#
#
# model-00002-of-00004.safetensors:  26% 1.29G/5.00G [00:09<00:28, 131MB/s]
#
#
#
# model-00003-of-00004.safetensors:  28% 1.39G/4.93G [00:09<00:25, 139MB/s]
# model-00001-of-00004.safetensors:  27% 1.31G/4.94G [00:09<00:27, 130MB/s]
#
#
# model-00002-of-00004.safetensors:  26% 1.31G/5.00G [00:09<00:29, 126MB/s]
#
#
#
# model-00003-of-00004.safetensors:  29% 1.42G/4.93G [00:09<00:28, 124MB/s]
# model-00001-of-00004.safetensors:  27% 1.33G/4.94G [00:09<00:29, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  27% 1.33G/5.00G [00:09<00:29, 125MB/s]
#
#
#
# model-00003-of-00004.safetensors:  29% 1.44G/4.93G [00:09<00:28, 123MB/s]
# model-00001-of-00004.safetensors:  27% 1.35G/4.94G [00:10<00:33, 107MB/s]
#
#
#
# model-00003-of-00004.safetensors:  30% 1.46G/4.93G [00:10<00:29, 117MB/s]
#
#
# model-00002-of-00004.safetensors:  27% 1.35G/5.00G [00:10<00:39, 93.1MB/s]
# model-00001-of-00004.safetensors:  28% 1.38G/4.94G [00:10<00:38, 93.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  30% 1.48G/4.93G [00:10<00:37, 92.7MB/s]
#
#
# model-00002-of-00004.safetensors:  27% 1.37G/5.00G [00:10<00:42, 84.5MB/s]
# model-00001-of-00004.safetensors:  29% 1.43G/4.94G [00:10<00:25, 136MB/s]
#
#
#
# model-00003-of-00004.safetensors:  31% 1.52G/4.93G [00:10<00:24, 142MB/s]
#
#
# model-00002-of-00004.safetensors:  28% 1.42G/5.00G [00:10<00:29, 120MB/s]
# model-00001-of-00004.safetensors:  29% 1.45G/4.94G [00:10<00:24, 144MB/s]
#
#
#
# model-00003-of-00004.safetensors:  31% 1.54G/4.93G [00:10<00:23, 147MB/s]
#
#
# model-00002-of-00004.safetensors:  29% 1.45G/5.00G [00:10<00:26, 133MB/s]
# model-00001-of-00004.safetensors:  30% 1.47G/4.94G [00:11<00:35, 98.6MB/s]
#
#
# model-00002-of-00004.safetensors:  29% 1.47G/5.00G [00:11<00:30, 115MB/s]
#
#
#
# model-00003-of-00004.safetensors:  32% 1.56G/4.93G [00:11<00:34, 97.6MB/s]
#
#
# model-00002-of-00004.safetensors:  30% 1.50G/5.00G [00:11<00:26, 130MB/s]
#
#
#
# model-00003-of-00004.safetensors:  32% 1.59G/4.93G [00:11<00:28, 116MB/s]
# model-00001-of-00004.safetensors:  31% 1.51G/4.94G [00:11<00:28, 120MB/s]
#
#
# model-00002-of-00004.safetensors:  31% 1.54G/5.00G [00:11<00:20, 167MB/s]
# model-00001-of-00004.safetensors:  31% 1.54G/4.94G [00:11<00:23, 142MB/s]
#
#
# model-00002-of-00004.safetensors:  31% 1.56G/5.00G [00:11<00:20, 168MB/s]
#
#
#
# model-00003-of-00004.safetensors:  33% 1.61G/4.93G [00:11<00:32, 102MB/s]
# model-00001-of-00004.safetensors:  32% 1.56G/4.94G [00:11<00:22, 149MB/s]
#
#
#
# model-00003-of-00004.safetensors:  33% 1.64G/4.93G [00:11<00:29, 110MB/s]
#
#
# model-00002-of-00004.safetensors:  32% 1.58G/5.00G [00:11<00:24, 137MB/s]
#
#
#
# model-00003-of-00004.safetensors:  34% 1.67G/4.93G [00:11<00:24, 134MB/s]
#
#
# model-00002-of-00004.safetensors:  32% 1.60G/5.00G [00:11<00:23, 147MB/s]
#
#
#
# model-00003-of-00004.safetensors:  34% 1.69G/4.93G [00:11<00:23, 135MB/s]
#
#
# model-00002-of-00004.safetensors:  33% 1.63G/5.00G [00:12<00:23, 142MB/s]
#
#
#
# model-00003-of-00004.safetensors:  35% 1.72G/4.93G [00:12<00:19, 166MB/s]
# model-00001-of-00004.safetensors:  32% 1.58G/4.94G [00:12<00:40, 83.4MB/s]
#
#
# model-00002-of-00004.safetensors:  33% 1.65G/5.00G [00:12<00:21, 156MB/s]
#
#
#
# model-00003-of-00004.safetensors:  35% 1.74G/4.93G [00:12<00:19, 167MB/s]
# model-00001-of-00004.safetensors:  32% 1.60G/4.94G [00:12<00:34, 98.0MB/s]
#
#
# model-00002-of-00004.safetensors:  33% 1.67G/5.00G [00:12<00:22, 148MB/s]
#
#
#
# model-00003-of-00004.safetensors:  36% 1.76G/4.93G [00:12<00:19, 160MB/s]
# model-00001-of-00004.safetensors:  33% 1.63G/4.94G [00:12<00:30, 107MB/s]
#
#
# model-00002-of-00004.safetensors:  34% 1.69G/5.00G [00:12<00:27, 121MB/s]
# model-00001-of-00004.safetensors:  33% 1.65G/4.94G [00:12<00:31, 104MB/s]
# model-00001-of-00004.safetensors:  34% 1.67G/4.94G [00:12<00:33, 97.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  36% 1.78G/4.93G [00:12<00:36, 87.1MB/s]
#
#
# model-00002-of-00004.safetensors:  34% 1.71G/5.00G [00:12<00:37, 88.7MB/s]
# model-00001-of-00004.safetensors:  34% 1.70G/4.94G [00:12<00:25, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  37% 1.81G/4.93G [00:12<00:27, 115MB/s]
#
#
# model-00002-of-00004.safetensors:  35% 1.74G/5.00G [00:13<00:28, 116MB/s]
# model-00001-of-00004.safetensors:  35% 1.73G/4.94G [00:13<00:20, 154MB/s]
#
#
#
# model-00003-of-00004.safetensors:  37% 1.85G/4.93G [00:13<00:22, 135MB/s]
#
#
# model-00002-of-00004.safetensors:  35% 1.76G/5.00G [00:13<00:25, 127MB/s]
# model-00001-of-00004.safetensors:  35% 1.75G/4.94G [00:13<00:19, 160MB/s]
#
#
#
# model-00003-of-00004.safetensors:  38% 1.87G/4.93G [00:13<00:23, 133MB/s]
#
#
# model-00002-of-00004.safetensors:  36% 1.78G/5.00G [00:13<00:25, 129MB/s]
# model-00001-of-00004.safetensors:  36% 1.77G/4.94G [00:13<00:24, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  38% 1.89G/4.93G [00:13<00:23, 127MB/s]
#
#
# model-00002-of-00004.safetensors:  36% 1.80G/5.00G [00:13<00:25, 125MB/s]
# model-00001-of-00004.safetensors:  36% 1.79G/4.94G [00:13<00:23, 132MB/s]
#
#
#
# model-00003-of-00004.safetensors:  39% 1.91G/4.93G [00:13<00:22, 134MB/s]
#
#
# model-00002-of-00004.safetensors:  36% 1.82G/5.00G [00:13<00:23, 133MB/s]
# model-00001-of-00004.safetensors:  37% 1.81G/4.94G [00:13<00:23, 136MB/s]
#
#
# model-00002-of-00004.safetensors:  37% 1.85G/5.00G [00:13<00:23, 132MB/s]
# model-00001-of-00004.safetensors:  37% 1.84G/4.94G [00:13<00:22, 136MB/s]
#
#
# model-00002-of-00004.safetensors:  37% 1.87G/5.00G [00:13<00:22, 138MB/s]
# model-00001-of-00004.safetensors:  38% 1.86G/4.94G [00:14<00:22, 138MB/s]
#
#
# model-00002-of-00004.safetensors:  38% 1.89G/5.00G [00:14<00:22, 141MB/s]
# model-00001-of-00004.safetensors:  38% 1.88G/4.94G [00:14<00:22, 138MB/s]
#
#
# model-00002-of-00004.safetensors:  38% 1.91G/5.00G [00:14<00:23, 134MB/s]
# model-00001-of-00004.safetensors:  38% 1.90G/4.94G [00:14<00:22, 133MB/s]
#
#
#
# model-00003-of-00004.safetensors:  39% 1.93G/4.93G [00:14<00:47, 62.7MB/s]
#
#
# model-00002-of-00004.safetensors:  39% 1.93G/5.00G [00:14<00:23, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  40% 1.98G/4.93G [00:14<00:26, 111MB/s]
# model-00001-of-00004.safetensors:  39% 1.92G/4.94G [00:14<00:24, 121MB/s]
#
#
# model-00002-of-00004.safetensors:  39% 1.95G/5.00G [00:20<04:30, 11.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  41% 2.01G/4.93G [00:20<03:01, 16.1MB/s]
# model-00001-of-00004.safetensors:  39% 1.94G/4.94G [00:20<04:26, 11.3MB/s]
#
#
# model-00002-of-00004.safetensors:  39% 1.97G/5.00G [00:20<03:15, 15.5MB/s]
# model-00001-of-00004.safetensors:  39% 1.95G/4.94G [00:20<03:53, 12.8MB/s]
#
#
# model-00002-of-00004.safetensors:  40% 1.98G/5.00G [00:20<02:56, 17.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  41% 2.03G/4.93G [00:21<02:42, 17.8MB/s]
# model-00001-of-00004.safetensors:  40% 1.96G/4.94G [00:21<03:31, 14.1MB/s]
#
#
# model-00002-of-00004.safetensors:  40% 1.99G/5.00G [00:21<02:46, 18.1MB/s]
# model-00001-of-00004.safetensors:  40% 1.97G/4.94G [00:21<03:16, 15.1MB/s]
#
#
# model-00002-of-00004.safetensors:  40% 2.00G/5.00G [00:21<02:46, 17.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  42% 2.06G/4.93G [00:22<02:50, 16.9MB/s]
#
#
# model-00002-of-00004.safetensors:  40% 2.01G/5.00G [00:22<03:03, 16.2MB/s]
# model-00001-of-00004.safetensors:  40% 1.98G/4.94G [00:22<03:39, 13.5MB/s]
# model-00001-of-00004.safetensors:  40% 1.99G/4.94G [00:23<03:40, 13.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  42% 2.07G/4.93G [00:23<03:04, 15.5MB/s]
#
#
# model-00002-of-00004.safetensors:  40% 2.02G/5.00G [00:23<03:29, 14.2MB/s]
# model-00001-of-00004.safetensors:  41% 2.00G/4.94G [00:24<04:19, 11.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  42% 2.08G/4.93G [00:24<03:34, 13.3MB/s]
#
#
# model-00002-of-00004.safetensors:  41% 2.03G/5.00G [00:25<04:22, 11.3MB/s]
# model-00001-of-00004.safetensors:  41% 2.01G/4.94G [00:26<05:11, 9.41MB/s]
#
#
#
# model-00003-of-00004.safetensors:  42% 2.09G/4.93G [00:26<04:14, 11.2MB/s]
#
#
# model-00002-of-00004.safetensors:  41% 2.04G/5.00G [00:26<05:04, 9.70MB/s]
# model-00001-of-00004.safetensors:  41% 2.02G/4.94G [00:27<05:10, 9.39MB/s]
#
#
#
# model-00003-of-00004.safetensors:  43% 2.10G/4.93G [00:27<04:24, 10.7MB/s]
#
#
# model-00002-of-00004.safetensors:  41% 2.06G/5.00G [00:27<04:57, 9.88MB/s]
#
#
#
# model-00003-of-00004.safetensors:  43% 2.11G/4.93G [00:27<03:33, 13.2MB/s]
# model-00001-of-00004.safetensors:  41% 2.03G/4.94G [00:27<03:58, 12.2MB/s]
#
#
# model-00002-of-00004.safetensors:  41% 2.07G/5.00G [00:27<03:47, 12.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  43% 2.13G/4.93G [00:27<02:11, 21.2MB/s]
# model-00001-of-00004.safetensors:  42% 2.06G/4.94G [00:27<02:18, 20.9MB/s]
#
#
# model-00002-of-00004.safetensors:  42% 2.09G/5.00G [00:27<02:11, 22.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  44% 2.16G/4.93G [00:28<01:14, 37.1MB/s]
# model-00001-of-00004.safetensors:  42% 2.09G/4.94G [00:28<01:14, 38.6MB/s]
#
#
# model-00002-of-00004.safetensors:  42% 2.12G/5.00G [00:28<01:11, 40.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  44% 2.19G/4.93G [00:28<00:48, 56.5MB/s]
# model-00001-of-00004.safetensors:  43% 2.13G/4.94G [00:28<00:41, 67.7MB/s]
#
#
# model-00002-of-00004.safetensors:  43% 2.15G/5.00G [00:28<00:45, 62.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  45% 2.22G/4.93G [00:28<00:34, 78.3MB/s]
# model-00001-of-00004.safetensors:  44% 2.16G/4.94G [00:28<00:31, 89.0MB/s]
#
#
# model-00002-of-00004.safetensors:  44% 2.18G/5.00G [00:28<00:33, 84.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  46% 2.24G/4.93G [00:28<00:32, 81.8MB/s]
# model-00001-of-00004.safetensors:  44% 2.18G/4.94G [00:28<00:31, 87.3MB/s]
#
#
# model-00002-of-00004.safetensors:  44% 2.20G/5.00G [00:28<00:33, 83.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  46% 2.26G/4.93G [00:28<00:36, 73.8MB/s]
# model-00001-of-00004.safetensors:  45% 2.20G/4.94G [00:28<00:35, 77.2MB/s]
#
#
# model-00002-of-00004.safetensors:  44% 2.22G/5.00G [00:28<00:37, 73.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  46% 2.29G/4.93G [00:29<00:41, 63.6MB/s]
# model-00001-of-00004.safetensors:  45% 2.22G/4.94G [00:29<00:41, 65.1MB/s]
#
#
# model-00002-of-00004.safetensors:  45% 2.24G/5.00G [00:29<00:44, 62.2MB/s]
#
#
# model-00002-of-00004.safetensors:  45% 2.25G/5.00G [00:29<00:44, 62.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  47% 2.31G/4.93G [00:29<00:42, 61.7MB/s]
# model-00001-of-00004.safetensors:  45% 2.24G/4.94G [00:29<00:42, 64.0MB/s]
#
#
# model-00002-of-00004.safetensors:  45% 2.26G/5.00G [00:29<00:43, 62.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  47% 2.32G/4.93G [00:29<00:42, 61.0MB/s]
# model-00001-of-00004.safetensors:  46% 2.25G/4.94G [00:29<00:42, 62.6MB/s]
#
#
# model-00002-of-00004.safetensors:  46% 2.28G/5.00G [00:29<00:44, 60.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  47% 2.33G/4.93G [00:30<00:43, 60.4MB/s]
# model-00001-of-00004.safetensors:  46% 2.26G/4.94G [00:30<00:42, 62.7MB/s]
#
#
# model-00002-of-00004.safetensors:  46% 2.29G/5.00G [00:30<00:42, 63.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  48% 2.35G/4.93G [00:30<00:34, 75.2MB/s]
# model-00001-of-00004.safetensors:  46% 2.29G/4.94G [00:30<00:34, 77.6MB/s]
#
#
# model-00002-of-00004.safetensors:  46% 2.31G/5.00G [00:30<00:34, 77.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  48% 2.36G/4.93G [00:30<00:32, 78.8MB/s]
# model-00001-of-00004.safetensors:  46% 2.30G/4.94G [00:30<00:34, 76.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  48% 2.37G/4.93G [00:30<00:32, 78.9MB/s]
# model-00001-of-00004.safetensors:  47% 2.31G/4.94G [00:30<00:33, 78.0MB/s]
#
#
# model-00002-of-00004.safetensors:  46% 2.32G/5.00G [00:30<00:43, 61.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  48% 2.38G/4.93G [00:30<00:33, 76.3MB/s]
# model-00001-of-00004.safetensors:  47% 2.32G/4.94G [00:30<00:33, 78.2MB/s]
#
#
# model-00002-of-00004.safetensors:  47% 2.34G/5.00G [00:30<00:33, 79.9MB/s]
# model-00001-of-00004.safetensors:  47% 2.33G/4.94G [00:30<00:33, 78.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  49% 2.39G/4.93G [00:30<00:34, 72.5MB/s]
#
#
# model-00002-of-00004.safetensors:  47% 2.37G/5.00G [00:30<00:22, 116MB/s]
# model-00001-of-00004.safetensors:  48% 2.36G/4.94G [00:30<00:21, 122MB/s]
#
#
#
# model-00003-of-00004.safetensors:  49% 2.43G/4.93G [00:30<00:19, 131MB/s]
#
#
# model-00002-of-00004.safetensors:  48% 2.41G/5.00G [00:30<00:15, 167MB/s]
# model-00001-of-00004.safetensors:  49% 2.40G/4.94G [00:31<00:14, 180MB/s]
#
#
#
# model-00003-of-00004.safetensors:  50% 2.47G/4.93G [00:31<00:13, 184MB/s]
#
#
# model-00002-of-00004.safetensors:  49% 2.45G/5.00G [00:31<00:11, 214MB/s]
# model-00001-of-00004.safetensors:  49% 2.44G/4.94G [00:31<00:11, 227MB/s]
#
#
#
# model-00003-of-00004.safetensors:  51% 2.52G/4.93G [00:31<00:10, 232MB/s]
#
#
# model-00002-of-00004.safetensors:  50% 2.50G/5.00G [00:31<00:09, 256MB/s]
# model-00001-of-00004.safetensors:  50% 2.49G/4.94G [00:31<00:09, 260MB/s]
#
#
#
# model-00003-of-00004.safetensors:  52% 2.56G/4.93G [00:31<00:09, 261MB/s]
#
#
# model-00002-of-00004.safetensors:  51% 2.54G/5.00G [00:31<00:08, 278MB/s]
# model-00001-of-00004.safetensors:  51% 2.52G/4.94G [00:31<00:10, 231MB/s]
#
#
#
# model-00003-of-00004.safetensors:  53% 2.59G/4.93G [00:31<00:09, 236MB/s]
#
#
# model-00002-of-00004.safetensors:  51% 2.57G/5.00G [00:31<00:11, 206MB/s]
# model-00001-of-00004.safetensors:  52% 2.55G/4.94G [00:31<00:13, 179MB/s]
#
#
#
# model-00003-of-00004.safetensors:  53% 2.62G/4.93G [00:31<00:12, 181MB/s]
#
#
# model-00002-of-00004.safetensors:  52% 2.60G/5.00G [00:31<00:11, 211MB/s]
# model-00001-of-00004.safetensors:  52% 2.57G/4.94G [00:31<00:14, 163MB/s]
#
#
#
# model-00003-of-00004.safetensors:  54% 2.65G/4.93G [00:31<00:13, 164MB/s]
# model-00001-of-00004.safetensors:  52% 2.59G/4.94G [00:32<00:14, 161MB/s]
#
#
# model-00002-of-00004.safetensors:  53% 2.63G/5.00G [00:32<00:14, 163MB/s]
#
#
#
# model-00003-of-00004.safetensors:  54% 2.67G/4.93G [00:32<00:13, 164MB/s]
#
#
# model-00002-of-00004.safetensors:  53% 2.65G/5.00G [00:32<00:15, 156MB/s]
# model-00001-of-00004.safetensors:  53% 2.61G/4.94G [00:32<00:16, 141MB/s]
#
#
#
# model-00003-of-00004.safetensors:  55% 2.69G/4.93G [00:32<00:15, 148MB/s]
#
#
# model-00002-of-00004.safetensors:  53% 2.67G/5.00G [00:32<00:16, 143MB/s]
# model-00001-of-00004.safetensors:  53% 2.63G/4.94G [00:32<00:17, 132MB/s]
#
#
#
# model-00003-of-00004.safetensors:  55% 2.72G/4.93G [00:32<00:15, 141MB/s]
#
#
# model-00002-of-00004.safetensors:  54% 2.69G/5.00G [00:32<00:17, 135MB/s]
# model-00001-of-00004.safetensors:  54% 2.65G/4.94G [00:32<00:17, 132MB/s]
#
#
# model-00002-of-00004.safetensors:  54% 2.72G/5.00G [00:32<00:15, 144MB/s]
#
#
#
# model-00003-of-00004.safetensors:  56% 2.74G/4.93G [00:32<00:18, 121MB/s]
# model-00001-of-00004.safetensors:  54% 2.67G/4.94G [00:32<00:18, 126MB/s]
#
#
#
# model-00003-of-00004.safetensors:  56% 2.76G/4.93G [00:32<00:17, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  55% 2.74G/5.00G [00:32<00:16, 137MB/s]
# model-00001-of-00004.safetensors:  55% 2.69G/4.94G [00:33<00:21, 106MB/s]
#
#
# model-00002-of-00004.safetensors:  55% 2.76G/5.00G [00:33<00:18, 118MB/s]
#
#
#
# model-00003-of-00004.safetensors:  56% 2.78G/4.93G [00:33<00:19, 108MB/s]
# model-00001-of-00004.safetensors:  55% 2.72G/4.94G [00:33<00:20, 107MB/s]
#
#
# model-00002-of-00004.safetensors:  56% 2.78G/5.00G [00:33<00:19, 113MB/s]
#
#
#
# model-00003-of-00004.safetensors:  57% 2.80G/4.93G [00:33<00:20, 105MB/s]
# model-00001-of-00004.safetensors:  55% 2.74G/4.94G [00:33<00:22, 98.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  57% 2.82G/4.93G [00:33<00:20, 101MB/s]
#
#
# model-00002-of-00004.safetensors:  56% 2.80G/5.00G [00:33<00:21, 103MB/s]
# model-00001-of-00004.safetensors:  56% 2.75G/4.94G [00:33<00:22, 97.6MB/s]
#
#
# model-00002-of-00004.safetensors:  56% 2.82G/5.00G [00:33<00:20, 105MB/s]
#
#
#
# model-00003-of-00004.safetensors:  58% 2.84G/4.93G [00:33<00:20, 101MB/s]
# model-00001-of-00004.safetensors:  56% 2.77G/4.94G [00:33<00:20, 105MB/s]
#
#
# model-00002-of-00004.safetensors:  57% 2.85G/5.00G [00:33<00:15, 140MB/s]
#
#
#
# model-00003-of-00004.safetensors:  58% 2.87G/4.93G [00:33<00:15, 136MB/s]
# model-00001-of-00004.safetensors:  57% 2.80G/4.94G [00:33<00:15, 141MB/s]
#
#
# model-00002-of-00004.safetensors:  58% 2.89G/5.00G [00:33<00:10, 192MB/s]
#
#
#
# model-00003-of-00004.safetensors:  59% 2.92G/4.93G [00:33<00:10, 186MB/s]
# model-00001-of-00004.safetensors:  57% 2.84G/4.94G [00:33<00:11, 190MB/s]
#
#
# model-00002-of-00004.safetensors:  59% 2.93G/5.00G [00:34<00:11, 188MB/s]
#
#
#
# model-00003-of-00004.safetensors:  60% 2.95G/4.93G [00:34<00:11, 175MB/s]
# model-00001-of-00004.safetensors:  58% 2.87G/4.94G [00:34<00:12, 171MB/s]
#
#
#
# model-00003-of-00004.safetensors:  60% 2.97G/4.93G [00:34<00:12, 152MB/s]
#
#
# model-00002-of-00004.safetensors:  59% 2.96G/5.00G [00:34<00:13, 149MB/s]
# model-00001-of-00004.safetensors:  59% 2.89G/4.94G [00:34<00:14, 144MB/s]
#
#
#
# model-00003-of-00004.safetensors:  61% 2.99G/4.93G [00:34<00:14, 133MB/s]
#
#
# model-00002-of-00004.safetensors:  60% 2.98G/5.00G [00:34<00:14, 137MB/s]
# model-00001-of-00004.safetensors:  59% 2.92G/4.94G [00:34<00:15, 133MB/s]
#
#
#
# model-00003-of-00004.safetensors:  61% 3.01G/4.93G [00:34<00:15, 127MB/s]
#
#
# model-00002-of-00004.safetensors:  60% 3.00G/5.00G [00:34<00:16, 123MB/s]
# model-00001-of-00004.safetensors:  59% 2.94G/4.94G [00:34<00:16, 119MB/s]
#
#
#
# model-00003-of-00004.safetensors:  62% 3.03G/4.93G [00:34<00:17, 110MB/s]
# model-00001-of-00004.safetensors:  60% 2.96G/4.94G [00:35<00:18, 107MB/s]
#
#
# model-00002-of-00004.safetensors:  60% 3.02G/5.00G [00:35<00:18, 107MB/s]
#
#
#
# model-00003-of-00004.safetensors:  62% 3.05G/4.93G [00:35<00:18, 100MB/s]
#
#
# model-00002-of-00004.safetensors:  61% 3.04G/5.00G [00:35<00:19, 99.6MB/s]
# model-00001-of-00004.safetensors:  60% 2.98G/4.94G [00:35<00:20, 96.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  62% 3.07G/4.93G [00:35<00:18, 101MB/s]
#
#
# model-00002-of-00004.safetensors:  61% 3.06G/5.00G [00:35<00:17, 108MB/s]
# model-00001-of-00004.safetensors:  61% 3.00G/4.94G [00:35<00:18, 106MB/s]
#
#
#
# model-00003-of-00004.safetensors:  63% 3.10G/4.93G [00:35<00:13, 134MB/s]
#
#
# model-00002-of-00004.safetensors:  62% 3.09G/5.00G [00:35<00:13, 139MB/s]
# model-00001-of-00004.safetensors:  62% 3.04G/4.94G [00:35<00:12, 156MB/s]
#
#
#
# model-00003-of-00004.safetensors:  64% 3.15G/4.93G [00:35<00:09, 183MB/s]
#
#
# model-00002-of-00004.safetensors:  63% 3.14G/5.00G [00:35<00:09, 191MB/s]
# model-00001-of-00004.safetensors:  62% 3.08G/4.94G [00:35<00:09, 190MB/s]
#
#
#
# model-00003-of-00004.safetensors:  64% 3.18G/4.93G [00:35<00:09, 178MB/s]
#
#
# model-00002-of-00004.safetensors:  63% 3.17G/5.00G [00:35<00:11, 165MB/s]
# model-00001-of-00004.safetensors:  63% 3.11G/4.94G [00:36<00:11, 160MB/s]
#
#
#
# model-00003-of-00004.safetensors:  65% 3.20G/4.93G [00:36<00:11, 154MB/s]
#
#
# model-00002-of-00004.safetensors:  64% 3.19G/5.00G [00:36<00:12, 144MB/s]
# model-00001-of-00004.safetensors:  63% 3.14G/4.94G [00:36<00:13, 139MB/s]
#
#
#
# model-00003-of-00004.safetensors:  65% 3.22G/4.93G [00:36<00:12, 133MB/s]
#
#
# model-00002-of-00004.safetensors:  64% 3.21G/5.00G [00:36<00:14, 121MB/s]
# model-00001-of-00004.safetensors:  64% 3.16G/4.94G [00:36<00:15, 119MB/s]
#
#
#
# model-00003-of-00004.safetensors:  66% 3.24G/4.93G [00:36<00:14, 115MB/s]
#
#
# model-00002-of-00004.safetensors:  65% 3.23G/5.00G [00:36<00:15, 111MB/s]
# model-00001-of-00004.safetensors:  64% 3.18G/4.94G [00:36<00:16, 109MB/s]
#
#
#
# model-00003-of-00004.safetensors:  66% 3.26G/4.93G [00:36<00:15, 106MB/s]
#
#
# model-00002-of-00004.safetensors:  65% 3.25G/5.00G [00:36<00:16, 105MB/s]
# model-00001-of-00004.safetensors:  65% 3.20G/4.94G [00:36<00:15, 111MB/s]
#
#
#
# model-00003-of-00004.safetensors:  67% 3.28G/4.93G [00:36<00:14, 115MB/s]
#
#
#
# model-00003-of-00004.safetensors:  67% 3.30G/4.93G [00:37<00:12, 129MB/s]
#
#
# model-00002-of-00004.safetensors:  66% 3.28G/5.00G [00:37<00:13, 125MB/s]
# model-00001-of-00004.safetensors:  65% 3.23G/4.94G [00:37<00:12, 133MB/s]
#
#
#
# model-00003-of-00004.safetensors:  67% 3.32G/4.93G [00:37<00:12, 124MB/s]
#
#
# model-00002-of-00004.safetensors:  66% 3.30G/5.00G [00:37<00:14, 120MB/s]
# model-00001-of-00004.safetensors:  66% 3.25G/4.94G [00:37<00:13, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  68% 3.34G/4.93G [00:37<00:12, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  66% 3.32G/5.00G [00:37<00:14, 119MB/s]
# model-00001-of-00004.safetensors:  66% 3.27G/4.94G [00:37<00:13, 124MB/s]
#
#
#
# model-00003-of-00004.safetensors:  68% 3.37G/4.93G [00:37<00:12, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  67% 3.34G/5.00G [00:37<00:14, 117MB/s]
# model-00001-of-00004.safetensors:  67% 3.29G/4.94G [00:37<00:13, 121MB/s]
#
#
#
# model-00003-of-00004.safetensors:  69% 3.39G/4.93G [00:37<00:12, 126MB/s]
#
#
# model-00002-of-00004.safetensors:  67% 3.37G/5.00G [00:37<00:13, 120MB/s]
# model-00001-of-00004.safetensors:  67% 3.31G/4.94G [00:37<00:13, 124MB/s]
#
#
#
# model-00003-of-00004.safetensors:  69% 3.41G/4.93G [00:37<00:12, 125MB/s]
#
#
# model-00002-of-00004.safetensors:  68% 3.39G/5.00G [00:37<00:13, 124MB/s]
# model-00001-of-00004.safetensors:  67% 3.33G/4.94G [00:37<00:13, 123MB/s]
#
#
#
# model-00003-of-00004.safetensors:  70% 3.43G/4.93G [00:38<00:12, 122MB/s]
#
#
# model-00002-of-00004.safetensors:  68% 3.41G/5.00G [00:38<00:13, 122MB/s]
# model-00001-of-00004.safetensors:  68% 3.36G/4.94G [00:38<00:12, 123MB/s]
#
#
#
# model-00003-of-00004.safetensors:  70% 3.45G/4.93G [00:38<00:11, 126MB/s]
#
#
# model-00002-of-00004.safetensors:  69% 3.43G/5.00G [00:38<00:12, 126MB/s]
# model-00001-of-00004.safetensors:  68% 3.38G/4.94G [00:38<00:12, 127MB/s]
#
#
#
# model-00003-of-00004.safetensors:  70% 3.47G/4.93G [00:38<00:11, 127MB/s]
#
#
# model-00002-of-00004.safetensors:  69% 3.45G/5.00G [00:38<00:12, 126MB/s]
# model-00001-of-00004.safetensors:  69% 3.40G/4.94G [00:38<00:12, 127MB/s]
#
#
#
# model-00003-of-00004.safetensors:  71% 3.49G/4.93G [00:38<00:11, 121MB/s]
#
#
# model-00002-of-00004.safetensors:  69% 3.47G/5.00G [00:38<00:12, 124MB/s]
# model-00001-of-00004.safetensors:  69% 3.42G/4.94G [00:38<00:12, 122MB/s]
#
#
#
# model-00003-of-00004.safetensors:  71% 3.51G/4.93G [00:38<00:11, 118MB/s]
#
#
# model-00002-of-00004.safetensors:  70% 3.49G/5.00G [00:38<00:12, 117MB/s]
# model-00001-of-00004.safetensors:  70% 3.44G/4.94G [00:38<00:13, 115MB/s]
#
#
#
# model-00003-of-00004.safetensors:  72% 3.53G/4.93G [00:39<00:14, 97.6MB/s]
#
#
# model-00002-of-00004.safetensors:  70% 3.51G/5.00G [00:39<00:15, 94.7MB/s]
# model-00001-of-00004.safetensors:  70% 3.46G/4.94G [00:39<00:15, 93.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  72% 3.54G/4.93G [00:39<00:15, 87.2MB/s]
#
#
# model-00002-of-00004.safetensors:  70% 3.52G/5.00G [00:39<00:16, 90.8MB/s]
# model-00001-of-00004.safetensors:  70% 3.47G/4.94G [00:39<00:17, 84.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  72% 3.55G/4.93G [00:39<00:17, 78.1MB/s]
#
#
# model-00002-of-00004.safetensors:  71% 3.53G/5.00G [00:39<00:18, 80.6MB/s]
# model-00001-of-00004.safetensors:  70% 3.48G/4.94G [00:39<00:17, 81.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  72% 3.57G/4.93G [00:39<00:19, 70.6MB/s]
#
#
# model-00002-of-00004.safetensors:  71% 3.54G/5.00G [00:39<00:20, 71.5MB/s]
# model-00001-of-00004.safetensors:  71% 3.49G/4.94G [00:39<00:20, 70.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  73% 3.58G/4.93G [00:39<00:21, 63.3MB/s]
#
#
# model-00002-of-00004.safetensors:  71% 3.55G/5.00G [00:39<00:24, 58.6MB/s]
# model-00001-of-00004.safetensors:  71% 3.50G/4.94G [00:40<00:26, 54.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  73% 3.59G/4.93G [00:40<00:28, 46.6MB/s]
#
#
# model-00002-of-00004.safetensors:  71% 3.57G/5.00G [00:40<00:37, 38.7MB/s]
# model-00001-of-00004.safetensors:  71% 3.51G/4.94G [00:45<03:40, 6.49MB/s]
#
#
#
# model-00003-of-00004.safetensors:  73% 3.60G/4.93G [00:46<03:37, 6.11MB/s]
#
#
# model-00002-of-00004.safetensors:  72% 3.58G/5.00G [00:46<03:50, 6.17MB/s]
# model-00001-of-00004.safetensors:  71% 3.52G/4.94G [00:46<02:51, 8.28MB/s]
#
#
#
# model-00003-of-00004.safetensors:  73% 3.61G/4.93G [00:46<02:55, 7.52MB/s]
#
#
# model-00002-of-00004.safetensors:  72% 3.59G/5.00G [00:47<03:23, 6.95MB/s]
# model-00001-of-00004.safetensors:  71% 3.53G/4.94G [00:47<02:41, 8.71MB/s]
#
#
#
# model-00003-of-00004.safetensors:  73% 3.62G/4.93G [00:48<03:20, 6.53MB/s]
#
#
# model-00002-of-00004.safetensors:  72% 3.60G/5.00G [00:50<04:20, 5.38MB/s]
# model-00001-of-00004.safetensors:  72% 3.54G/4.94G [00:50<03:50, 6.08MB/s]
#
#
#
# model-00003-of-00004.safetensors:  74% 3.63G/4.93G [00:51<03:51, 5.61MB/s]
# model-00001-of-00004.safetensors:  72% 3.55G/4.94G [00:52<04:05, 5.65MB/s]
#
#
# model-00002-of-00004.safetensors:  72% 3.61G/5.00G [00:52<04:29, 5.16MB/s]
#
#
#
# model-00003-of-00004.safetensors:  74% 3.64G/4.93G [00:55<04:57, 4.33MB/s]
# model-00001-of-00004.safetensors:  72% 3.57G/4.94G [00:57<05:52, 3.91MB/s]
#
#
# model-00002-of-00004.safetensors:  72% 3.62G/5.00G [00:57<06:16, 3.67MB/s]
#
#
#
# model-00003-of-00004.safetensors:  74% 3.65G/4.93G [01:01<07:20, 2.90MB/s]
#
#
# model-00002-of-00004.safetensors:  73% 3.63G/5.00G [01:04<08:52, 2.58MB/s]
# model-00001-of-00004.safetensors:  72% 3.58G/4.94G [01:04<08:49, 2.58MB/s]
#
#
#
# model-00003-of-00004.safetensors:  74% 3.66G/4.93G [01:08<09:04, 2.33MB/s]
#
#
# model-00002-of-00004.safetensors:  73% 3.64G/5.00G [01:09<09:50, 2.31MB/s]
# model-00001-of-00004.safetensors:  73% 3.59G/4.94G [01:09<09:40, 2.34MB/s]
#
#
#
# model-00003-of-00004.safetensors:  74% 3.67G/4.93G [01:10<07:37, 2.75MB/s]
# model-00001-of-00004.safetensors:  73% 3.60G/4.94G [01:10<07:00, 3.20MB/s]
#
#
# model-00002-of-00004.safetensors:  73% 3.65G/5.00G [01:10<07:07, 3.16MB/s]
#
#
#
# model-00003-of-00004.safetensors:  75% 3.69G/4.93G [01:10<04:06, 5.02MB/s]
# model-00001-of-00004.safetensors:  73% 3.62G/4.94G [01:10<03:47, 5.84MB/s]
#
#
# model-00002-of-00004.safetensors:  74% 3.68G/5.00G [01:10<03:07, 7.02MB/s]
#
#
#
# model-00003-of-00004.safetensors:  75% 3.71G/4.93G [01:10<02:28, 8.16MB/s]
# model-00001-of-00004.safetensors:  74% 3.64G/4.94G [01:10<02:17, 9.49MB/s]
#
#
# model-00002-of-00004.safetensors:  74% 3.71G/5.00G [01:10<01:44, 12.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  76% 3.74G/4.93G [01:10<01:21, 14.5MB/s]
# model-00001-of-00004.safetensors:  74% 3.67G/4.94G [01:10<01:16, 16.7MB/s]
#
#
# model-00002-of-00004.safetensors:  75% 3.73G/5.00G [01:10<01:16, 16.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  76% 3.76G/4.93G [01:10<01:00, 19.3MB/s]
# model-00001-of-00004.safetensors:  75% 3.69G/4.94G [01:11<00:56, 22.0MB/s]
#
#
# model-00002-of-00004.safetensors:  75% 3.75G/5.00G [01:11<00:55, 22.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  77% 3.80G/4.93G [01:11<00:37, 29.9MB/s]
# model-00001-of-00004.safetensors:  75% 3.72G/4.94G [01:11<00:35, 34.0MB/s]
#
#
# model-00002-of-00004.safetensors:  76% 3.79G/5.00G [01:11<00:35, 34.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  77% 3.82G/4.93G [01:11<00:30, 36.5MB/s]
# model-00001-of-00004.safetensors:  76% 3.74G/4.94G [01:11<00:29, 40.5MB/s]
#
#
# model-00002-of-00004.safetensors:  76% 3.81G/5.00G [01:11<00:29, 40.3MB/s]
# model-00001-of-00004.safetensors:  76% 3.76G/4.94G [01:11<00:23, 50.1MB/s]
#
#
# model-00002-of-00004.safetensors:  77% 3.83G/5.00G [01:11<00:22, 51.2MB/s]
# model-00001-of-00004.safetensors:  77% 3.79G/4.94G [01:11<00:18, 62.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  78% 3.84G/4.93G [01:11<00:26, 41.0MB/s]
#
#
# model-00002-of-00004.safetensors:  77% 3.85G/5.00G [01:11<00:18, 61.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  78% 3.86G/4.93G [01:11<00:20, 52.5MB/s]
# model-00001-of-00004.safetensors:  77% 3.81G/4.94G [01:11<00:16, 68.2MB/s]
#
#
# model-00002-of-00004.safetensors:  77% 3.87G/5.00G [01:12<00:16, 67.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  79% 3.88G/4.93G [01:12<00:17, 61.2MB/s]
# model-00001-of-00004.safetensors:  77% 3.83G/4.94G [01:12<00:13, 81.6MB/s]
#
#
# model-00002-of-00004.safetensors:  78% 3.90G/5.00G [01:12<00:11, 93.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  79% 3.91G/4.93G [01:12<00:11, 87.1MB/s]
# model-00001-of-00004.safetensors:  78% 3.86G/4.94G [01:12<00:10, 106MB/s]
#
#
# model-00002-of-00004.safetensors:  78% 3.92G/5.00G [01:12<00:10, 101MB/s]
#
#
#
# model-00003-of-00004.safetensors:  80% 3.93G/4.93G [01:12<00:10, 94.1MB/s]
# model-00001-of-00004.safetensors:  78% 3.88G/4.94G [01:12<00:10, 105MB/s]
#
#
# model-00002-of-00004.safetensors:  79% 3.94G/5.00G [01:12<00:10, 98.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  80% 3.95G/4.93G [01:12<00:10, 92.9MB/s]
# model-00001-of-00004.safetensors:  79% 3.90G/4.94G [01:12<00:11, 92.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  81% 3.97G/4.93G [01:12<00:10, 88.2MB/s]
#
#
# model-00002-of-00004.safetensors:  79% 3.96G/5.00G [01:12<00:12, 84.3MB/s]
# model-00001-of-00004.safetensors:  79% 3.92G/4.94G [01:12<00:10, 101MB/s]
#
#
#
# model-00003-of-00004.safetensors:  82% 4.02G/4.93G [01:12<00:07, 126MB/s]
#
#
# model-00002-of-00004.safetensors:  80% 4.01G/5.00G [01:13<00:08, 123MB/s]
# model-00001-of-00004.safetensors:  80% 3.95G/4.94G [01:13<00:07, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  82% 4.04G/4.93G [01:13<00:07, 125MB/s]
# model-00001-of-00004.safetensors:  80% 3.97G/4.94G [01:13<00:07, 125MB/s]
#
#
# model-00002-of-00004.safetensors:  81% 4.03G/5.00G [01:13<00:08, 116MB/s]
#
#
#
# model-00003-of-00004.safetensors:  82% 4.06G/4.93G [01:13<00:06, 129MB/s]
#
#
# model-00002-of-00004.safetensors:  81% 4.05G/5.00G [01:13<00:07, 120MB/s]
# model-00001-of-00004.safetensors:  81% 4.00G/4.94G [01:13<00:08, 116MB/s]
#
#
#
# model-00003-of-00004.safetensors:  83% 4.08G/4.93G [01:13<00:06, 131MB/s]
#
#
# model-00002-of-00004.safetensors:  81% 4.07G/5.00G [01:13<00:07, 124MB/s]
# model-00001-of-00004.safetensors:  81% 4.02G/4.94G [01:13<00:08, 114MB/s]
#
#
# model-00002-of-00004.safetensors:  82% 4.09G/5.00G [01:13<00:06, 138MB/s]
#
#
#
# model-00003-of-00004.safetensors:  83% 4.10G/4.93G [01:13<00:06, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  82% 4.11G/5.00G [01:13<00:06, 143MB/s]
#
#
#
# model-00003-of-00004.safetensors:  84% 4.12G/4.93G [01:13<00:06, 128MB/s]
# model-00001-of-00004.safetensors:  82% 4.04G/4.94G [01:13<00:08, 106MB/s]
# model-00001-of-00004.safetensors:  82% 4.06G/4.94G [01:13<00:07, 123MB/s]
#
#
#
# model-00003-of-00004.safetensors:  84% 4.14G/4.93G [01:14<00:07, 112MB/s]
#
#
# model-00002-of-00004.safetensors:  83% 4.13G/5.00G [01:14<00:08, 104MB/s]
#
#
#
# model-00003-of-00004.safetensors:  84% 4.16G/4.93G [01:15<00:15, 50.3MB/s]
# model-00001-of-00004.safetensors:  83% 4.08G/4.94G [01:15<00:18, 45.7MB/s]
#
#
# model-00002-of-00004.safetensors:  83% 4.15G/5.00G [01:15<00:17, 47.3MB/s]
# model-00001-of-00004.safetensors:  83% 4.09G/4.94G [01:15<00:22, 38.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  85% 4.17G/4.93G [01:15<00:20, 36.3MB/s]
#
#
# model-00002-of-00004.safetensors:  83% 4.16G/5.00G [01:17<00:45, 18.3MB/s]
# model-00001-of-00004.safetensors:  83% 4.10G/4.94G [01:17<00:52, 16.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  85% 4.18G/4.93G [01:17<00:48, 15.3MB/s]
#
#
# model-00002-of-00004.safetensors:  83% 4.17G/5.00G [01:18<00:48, 17.1MB/s]
# model-00001-of-00004.safetensors:  83% 4.11G/4.94G [01:18<00:57, 14.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  85% 4.19G/4.93G [01:19<00:53, 13.7MB/s]
#
#
# model-00002-of-00004.safetensors:  84% 4.18G/5.00G [01:19<00:54, 15.0MB/s]
# model-00001-of-00004.safetensors:  83% 4.12G/4.94G [01:19<01:04, 12.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  85% 4.20G/4.93G [01:20<00:57, 12.6MB/s]
#
#
# model-00002-of-00004.safetensors:  84% 4.19G/5.00G [01:20<01:01, 13.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  86% 4.22G/4.93G [01:21<01:02, 11.3MB/s]
#
#
# model-00002-of-00004.safetensors:  84% 4.20G/5.00G [01:21<01:06, 11.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  86% 4.23G/4.93G [01:22<01:00, 11.6MB/s]
# model-00001-of-00004.safetensors:  84% 4.13G/4.94G [01:22<01:32, 8.73MB/s]
#
#
# model-00002-of-00004.safetensors:  84% 4.22G/5.00G [01:22<01:05, 12.0MB/s]
# model-00001-of-00004.safetensors:  84% 4.14G/4.94G [01:24<01:52, 7.13MB/s]
#
#
#
# model-00003-of-00004.safetensors:  86% 4.24G/4.93G [01:24<01:24, 8.22MB/s]
#
#
# model-00002-of-00004.safetensors:  85% 4.23G/5.00G [01:24<01:30, 8.57MB/s]
#
#
#
# model-00003-of-00004.safetensors:  86% 4.25G/4.93G [01:24<01:01, 11.0MB/s]
# model-00001-of-00004.safetensors:  84% 4.15G/4.94G [01:24<01:23, 9.52MB/s]
#
#
# model-00002-of-00004.safetensors:  85% 4.24G/5.00G [01:24<01:06, 11.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  87% 4.27G/4.93G [01:24<00:34, 19.1MB/s]
# model-00001-of-00004.safetensors:  84% 4.17G/4.94G [01:24<00:47, 16.4MB/s]
#
#
# model-00002-of-00004.safetensors:  85% 4.26G/5.00G [01:24<00:37, 19.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  87% 4.29G/4.93G [01:24<00:22, 29.0MB/s]
# model-00001-of-00004.safetensors:  85% 4.19G/4.94G [01:24<00:30, 24.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  87% 4.31G/4.93G [01:24<00:15, 38.8MB/s]
#
#
# model-00002-of-00004.safetensors:  86% 4.28G/5.00G [01:24<00:26, 27.0MB/s]
# model-00001-of-00004.safetensors:  85% 4.22G/4.94G [01:25<00:21, 33.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  88% 4.32G/4.93G [01:25<00:13, 43.5MB/s]
#
#
# model-00002-of-00004.safetensors:  86% 4.31G/5.00G [01:25<00:15, 43.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  88% 4.34G/4.93G [01:25<00:10, 57.7MB/s]
#
#
# model-00002-of-00004.safetensors:  87% 4.34G/5.00G [01:25<00:10, 63.3MB/s]
# model-00001-of-00004.safetensors:  85% 4.23G/4.94G [01:25<00:21, 33.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  89% 4.36G/4.93G [01:25<00:07, 76.5MB/s]
# model-00001-of-00004.safetensors:  87% 4.28G/4.94G [01:25<00:09, 71.0MB/s]
#
#
# model-00002-of-00004.safetensors:  87% 4.36G/5.00G [01:25<00:08, 72.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  89% 4.38G/4.93G [01:25<00:06, 88.4MB/s]
# model-00001-of-00004.safetensors:  87% 4.30G/4.94G [01:25<00:07, 83.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  89% 4.40G/4.93G [01:25<00:05, 97.6MB/s]
#
#
# model-00002-of-00004.safetensors:  88% 4.38G/5.00G [01:25<00:07, 77.8MB/s]
# model-00001-of-00004.safetensors:  87% 4.32G/4.94G [01:25<00:06, 98.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  90% 4.42G/4.93G [01:25<00:04, 108MB/s]
# model-00001-of-00004.safetensors:  88% 4.34G/4.94G [01:25<00:05, 105MB/s]
#
#
# model-00002-of-00004.safetensors:  88% 4.40G/5.00G [01:25<00:07, 84.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  90% 4.45G/4.93G [01:26<00:04, 110MB/s]
# model-00001-of-00004.safetensors:  88% 4.36G/4.94G [01:26<00:05, 115MB/s]
#
#
# model-00002-of-00004.safetensors:  89% 4.42G/5.00G [01:26<00:06, 94.0MB/s]
# model-00001-of-00004.safetensors:  89% 4.38G/4.94G [01:26<00:04, 117MB/s]
#
#
#
# model-00003-of-00004.safetensors:  91% 4.47G/4.93G [01:26<00:04, 112MB/s]
#
#
# model-00002-of-00004.safetensors:  89% 4.45G/5.00G [01:26<00:05, 101MB/s]
# model-00001-of-00004.safetensors:  89% 4.40G/4.94G [01:26<00:04, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  89% 4.47G/5.00G [01:26<00:04, 118MB/s]
#
#
#
# model-00003-of-00004.safetensors:  91% 4.49G/4.93G [01:26<00:04, 104MB/s]
# model-00001-of-00004.safetensors:  90% 4.42G/4.94G [01:26<00:04, 115MB/s]
#
#
#
# model-00003-of-00004.safetensors:  92% 4.51G/4.93G [01:26<00:03, 118MB/s]
#
#
# model-00002-of-00004.safetensors:  90% 4.49G/5.00G [01:26<00:04, 112MB/s]
# model-00001-of-00004.safetensors:  90% 4.45G/4.94G [01:26<00:03, 129MB/s]
#
#
#
# model-00003-of-00004.safetensors:  92% 4.53G/4.93G [01:26<00:03, 119MB/s]
#
#
# model-00002-of-00004.safetensors:  90% 4.51G/5.00G [01:26<00:04, 113MB/s]
#
#
#
# model-00003-of-00004.safetensors:  92% 4.55G/4.93G [01:26<00:02, 130MB/s]
# model-00001-of-00004.safetensors:  90% 4.47G/4.94G [01:26<00:03, 122MB/s]
#
#
# model-00002-of-00004.safetensors:  91% 4.53G/5.00G [01:26<00:04, 107MB/s]
# model-00001-of-00004.safetensors:  91% 4.49G/4.94G [01:27<00:03, 133MB/s]
#
#
#
# model-00003-of-00004.safetensors:  93% 4.57G/4.93G [01:27<00:02, 132MB/s]
# model-00001-of-00004.safetensors:  91% 4.51G/4.94G [01:27<00:03, 145MB/s]
#
#
# model-00002-of-00004.safetensors:  91% 4.55G/5.00G [01:27<00:04, 108MB/s]
#
#
#
# model-00003-of-00004.safetensors:  93% 4.59G/4.93G [01:27<00:02, 129MB/s]
# model-00001-of-00004.safetensors:  92% 4.53G/4.94G [01:27<00:02, 142MB/s]
#
#
# model-00002-of-00004.safetensors:  91% 4.57G/5.00G [01:27<00:03, 111MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.61G/4.93G [01:27<00:02, 128MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.63G/4.93G [01:27<00:02, 137MB/s]
# model-00001-of-00004.safetensors:  92% 4.55G/4.94G [01:27<00:03, 123MB/s]
#
#
# model-00002-of-00004.safetensors:  92% 4.59G/5.00G [01:27<00:03, 111MB/s]
#
#
#
# model-00003-of-00004.safetensors:  94% 4.66G/4.93G [01:27<00:02, 121MB/s]
# model-00001-of-00004.safetensors:  92% 4.57G/4.94G [01:27<00:03, 112MB/s]
#
#
# model-00002-of-00004.safetensors:  92% 4.62G/5.00G [01:27<00:03, 121MB/s]
#
#
#
# model-00003-of-00004.safetensors:  95% 4.68G/4.93G [01:27<00:02, 104MB/s]
# model-00001-of-00004.safetensors:  93% 4.59G/4.94G [01:28<00:03, 94.8MB/s]
#
#
# model-00002-of-00004.safetensors:  93% 4.65G/5.00G [01:28<00:03, 104MB/s]
# model-00001-of-00004.safetensors:  93% 4.61G/4.94G [01:28<00:03, 92.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  95% 4.70G/4.93G [01:28<00:02, 92.8MB/s]
#
#
# model-00002-of-00004.safetensors:  93% 4.67G/5.00G [01:28<00:03, 96.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.71G/4.93G [01:28<00:02, 92.3MB/s]
# model-00001-of-00004.safetensors:  94% 4.62G/4.94G [01:28<00:03, 89.8MB/s]
#
#
# model-00002-of-00004.safetensors:  94% 4.68G/5.00G [01:28<00:03, 93.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.72G/4.93G [01:28<00:02, 92.3MB/s]
# model-00001-of-00004.safetensors:  94% 4.63G/4.94G [01:28<00:03, 89.9MB/s]
#
#
# model-00002-of-00004.safetensors:  94% 4.69G/5.00G [01:28<00:03, 92.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.73G/4.93G [01:28<00:02, 88.0MB/s]
# model-00001-of-00004.safetensors:  94% 4.65G/4.94G [01:28<00:03, 86.6MB/s]
#
#
# model-00002-of-00004.safetensors:  94% 4.70G/5.00G [01:28<00:03, 87.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.74G/4.93G [01:28<00:02, 86.0MB/s]
# model-00001-of-00004.safetensors:  94% 4.66G/4.94G [01:28<00:03, 84.8MB/s]
#
#
# model-00002-of-00004.safetensors:  94% 4.71G/5.00G [01:28<00:03, 85.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  96% 4.75G/4.93G [01:28<00:02, 85.4MB/s]
# model-00001-of-00004.safetensors:  94% 4.67G/4.94G [01:28<00:03, 85.2MB/s]
#
#
# model-00002-of-00004.safetensors:  94% 4.72G/5.00G [01:28<00:03, 87.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  97% 4.77G/4.93G [01:29<00:01, 95.8MB/s]
# model-00001-of-00004.safetensors:  95% 4.69G/4.94G [01:29<00:02, 95.6MB/s]
#
#
# model-00002-of-00004.safetensors:  95% 4.74G/5.00G [01:29<00:02, 96.6MB/s]
# model-00001-of-00004.safetensors:  95% 4.71G/4.94G [01:29<00:02, 117MB/s]
#
#
# model-00002-of-00004.safetensors:  95% 4.76G/5.00G [01:29<00:02, 119MB/s]
# model-00001-of-00004.safetensors:  96% 4.75G/4.94G [01:29<00:01, 181MB/s]
#
#
#
# model-00003-of-00004.safetensors:  97% 4.78G/4.93G [01:29<00:01, 73.7MB/s]
#
#
# model-00002-of-00004.safetensors:  96% 4.80G/5.00G [01:29<00:01, 182MB/s]
# model-00001-of-00004.safetensors:  97% 4.77G/4.94G [01:29<00:00, 178MB/s]
#
#
# model-00002-of-00004.safetensors:  96% 4.82G/5.00G [01:29<00:00, 184MB/s]
#
#
#
# model-00003-of-00004.safetensors:  98% 4.83G/4.93G [01:29<00:00, 148MB/s]
# model-00001-of-00004.safetensors:  97% 4.79G/4.94G [01:29<00:01, 151MB/s]
#
#
# model-00002-of-00004.safetensors:  97% 4.84G/5.00G [01:29<00:01, 150MB/s]
#
#
#
# model-00003-of-00004.safetensors:  99% 4.85G/4.93G [01:29<00:00, 127MB/s]
# model-00001-of-00004.safetensors:  97% 4.81G/4.94G [01:29<00:01, 130MB/s]
#
#
# model-00002-of-00004.safetensors:  97% 4.87G/5.00G [01:29<00:01, 126MB/s]
#
#
#
# model-00003-of-00004.safetensors:  99% 4.88G/4.93G [01:29<00:00, 116MB/s]
# model-00001-of-00004.safetensors:  98% 4.83G/4.94G [01:30<00:00, 113MB/s]
#
#
# model-00002-of-00004.safetensors:  98% 4.89G/5.00G [01:30<00:01, 113MB/s]
#
#
#
# model-00003-of-00004.safetensors:  99% 4.90G/4.93G [01:30<00:00, 108MB/s]
# model-00001-of-00004.safetensors:  98% 4.85G/4.94G [01:30<00:00, 104MB/s]
#
#
# model-00002-of-00004.safetensors:  98% 4.91G/5.00G [01:30<00:00, 104MB/s]
#
#
#
# model-00003-of-00004.safetensors: 100% 4.92G/4.93G [01:30<00:00, 99.7MB/s]
# model-00003-of-00004.safetensors: 100% 4.93G/4.93G [01:30<00:00, 54.4MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/model-00003-of-00004.safetensors
#
#
#
# model-00002-of-00004.safetensors:  99% 4.93G/5.00G [01:30<00:00, 103MB/s]
# model-00001-of-00004.safetensors:  99% 4.91G/4.94G [01:30<00:00, 133MB/s]
#
#
# model-00001-of-00004.safetensors: 100% 4.94G/4.94G [01:30<00:00, 54.5MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/model-00001-of-00004.safetensors
# model-00002-of-00004.safetensors: 100% 5.00G/5.00G [01:30<00:00, 55.1MB/s]
# Download complete. Moving file to checkpoints/llava-med-v1.5-mistral-7b/model-00002-of-00004.safetensors
# Fetching 12 files: 100% 12/12 [01:31<00:00,  7.59s/it]
# /content/checkpoints/llava-med-v1.5-mistral-7b

# %%
# Import necessary modules
from llava.model.builder import load_pretrained_model
from llava.mm_utils import process_images, tokenizer_image_token
from llava.conversation import conv_templates
from llava.constants import IMAGE_TOKEN_INDEX
from PIL import Image
import torch

# Load the model once
print("Loading model...")
tokenizer, model, image_processor, context_len = load_pretrained_model(
    model_path="/content/checkpoints/llava-med-v1.5-mistral-7b",
    model_base=None,
    model_name="llava-med-v1.5-mistral-7b"
)
print("Model loaded successfully!")
# Out:
# Loading model...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.76k [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Some weights of the model checkpoint at /content/checkpoints/llava-med-v1.5-mistral-7b were not used when initializing LlavaMistralForCausalLM: ['model.vision_tower.vision_tower.vision_model.embeddings.class_embedding', 'model.vision_tower.vision_tower.vision_model.embeddings.patch_embedding.weight', 'model.vision_tower.vision_tower.vision_model.embeddings.position_embedding.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm1.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm1.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm2.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.layer_norm2.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc1.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc1.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc2.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.mlp.fc2.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm1.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm1.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm2.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.layer_norm2.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc1.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc1.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc2.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.mlp.fc2.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm1.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm1.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm2.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.layer_norm2.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc1.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc1.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc2.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.mlp.fc2.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.bias', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.weight', 'model.vision_tower.vision_tower.vision_model.encoder.layers.10.sel ...
# - This IS expected if you are initializing LlavaMistralForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing LlavaMistralForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Model loaded successfully!

# %%
# @title Default title text
# Simple Inference
import os
import glob

# Set the test folder path
# test_folder = "/content/drive/MyDrive/preprocessed_combined_dataset_2/test"
test_folder = "/content/drive/MyDrive/preprocessed_pneumothorax/test"
# test_folder = "/content/lungs"

def generate_response(image_path, prompt):
    # Load and process the image
    image = Image.open(image_path).convert('RGB')
    image_tensor = process_images([image], image_processor, model.config)
    image_tensor = image_tensor.to(model.device, dtype=torch.float16)

    # Create conversation template
    conv = conv_templates["mistral_instruct"].copy()
    conv.append_message(conv.roles[0], f"\n{prompt}")
    conv.append_message(conv.roles[1], None)

    # Get the formatted prompt
    formatted_prompt = conv.get_prompt()

    # Tokenize the input
    input_ids = tokenizer_image_token(
        formatted_prompt,
        tokenizer,
        IMAGE_TOKEN_INDEX,
        return_tensors='pt'
    ).unsqueeze(0).to(model.device)

    # Generate response
    with torch.inference_mode():
        output_ids = model.generate(
            input_ids,
            images=image_tensor,
            do_sample=True,
            temperature=1,
            max_new_tokens=512,
            use_cache=True,
            pad_token_id=tokenizer.eos_token_id
        )

    # Decode the response
    response = tokenizer.decode(
        output_ids[0, input_ids.shape[1]:],
        skip_special_tokens=True
    ).strip()

    return response

# Get all image files in the test folder
# image_files = glob.glob(os.path.join(test_folder, "*.jpg"))
image_files = glob.glob(os.path.join(test_folder, "*.png"))
image_files.sort()  # Sort for consistent ordering

# Iterate through each image and classify
# prompt = "Classify the disease in this X-ray scan of the lungs as Pneumothorax or no finding: Please Explain"
prompt = "Classify the disease in this image: "
for image_path in image_files:
    print('a')
    print("a")
    image_filename = os.path.basename(image_path)
    print(f"\n--- Processing: {image_filename} ---")

    try:
        result = generate_response(image_path, prompt)
        print(f"Classification: {result}")
    except Exception as e:
        print(f"Error processing {image_filename}: {str(e)}")

    print("-" * 50)

# %%
# @title Default title text
#
import os
import glob
import pandas as pd

# Set the test folder path and CSV path
# test_folder = "/content/drive/MyDrive/preprocessed_combined_dataset_2/test"
# csv_path = "/content/drive/MyDrive/preprocessed_combined_dataset_2/test.csv"
test_folder = "/content/drive/MyDrive/preprocessed_pneumothorax/test"
csv_path = "/content/drive/MyDrive/preprocessed_pneumothorax/test.csv"

def generate_response(image_path, prompt):
    print(f"  Loading image: {image_path}")

    # Load and process the image
    image = Image.open(image_path).convert('RGB')
    print(f"  Image size: {image.size}")

    image_tensor = process_images([image], image_processor, model.config)
    image_tensor = image_tensor.to(model.device, dtype=torch.float16)
    print(f"  Image tensor shape: {image_tensor.shape}")

    # Create conversation template
    conv = conv_templates["mistral_instruct"].copy()
    conv.append_message(conv.roles[0], f"\n{prompt}")
    conv.append_message(conv.roles[1], None)

    # Get the formatted prompt
    formatted_prompt = conv.get_prompt()
    print(f"  Formatted prompt length: {len(formatted_prompt)}")

    # Tokenize the input
    input_ids = tokenizer_image_token(
        formatted_prompt,
        tokenizer,
        IMAGE_TOKEN_INDEX,
        return_tensors='pt'
    ).unsqueeze(0).to(model.device)
    print(f"  Input IDs shape: {input_ids.shape}")

    # Generate response with more conservative settings
    print("  Generating response...")
    with torch.inference_mode():
        output_ids = model.generate(
            input_ids,
            images=image_tensor,
            do_sample=False,  # Changed to deterministic
            temperature=.5,  # Higher temperature
            max_new_tokens=512,  # Reduced tokens
            use_cache=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
            stopping_criteria=None
        )

    print(f"  Output IDs shape: {output_ids.shape}")
    print(f"  Generated tokens: {output_ids.shape[1] - input_ids.shape[1]}")

    # Decode the response
    response = tokenizer.decode(
        output_ids[0, input_ids.shape[1]:],
        skip_special_tokens=True
    ).strip()

    print(f"  Raw response length: {len(response)}")

    return response

def classify_response(response):
    response_lower = response.lower()

    hs_keywords = [
        'hallervorden-spatz', 'hallervorden spatz', 'pkan',
        'pantothenate kinase', 'neurodegeneration with brain iron',
        'eye of the tiger', 'eye-of-the-tiger'
    ]

    hs_indirect_clues = [
        'iron deposits', 'abnormal iron accumulation',
        't2 hypointensity', 'eye of the tiger', 'globus pallidus'
    ]

    # Strong direct match
    for keyword in hs_keywords:
        if keyword in response_lower:
            return 1

    # Only trigger on indirect clues if abnormality is also mentioned
    if any(indirect in response_lower for indirect in hs_indirect_clues):
        if 'abnormal' in response_lower or 'consistent with disease' in response_lower:
            return 1

    # If clearly states normal
    if 'normal' in response_lower or 'no abnormality' in response_lower:
        return 0

    # Default to normal
    return 0


# Load the ground truth labels
df = pd.read_csv(csv_path)
print(f"Loaded {len(df)} test samples from CSV")

# Create dictionaries for quick lookup
filename_to_label = dict(zip(df.iloc[:, 0], df.iloc[:, 1]))

# Lists to store results
predictions = []
ground_truth = []
filenames = []

# Iterate through each image and classify
# prompt = "Classify the disease in this MRI scan of a brain: "
# prompt = "Is this a case of Hallervorden-Spatz disease or a normal brain T2 MRI? Please explain."
# prompt = "Classify this brain MRI as either normal or showing Hallervorden-Spatz disease."
prompt = "This is a T2-weighted MRI of the brain. Please identify if it shows signs of Pantothenate Kinase-Associated Neurodegeneration (PKAN)."

print("\n=== Starting Inference Accuracy Test ===\n")

for idx, (filename, true_label) in enumerate(filename_to_label.items()):
    image_path = os.path.join(test_folder, filename)

    # Check if image file exists
    if not os.path.exists(image_path):
        print(f"Warning: Image {filename} not found, skipping...")
        continue

    print(f"[{idx+1}/{len(filename_to_label)}] Processing: {filename}")
    print(f"Ground Truth: {true_label} ({'Normal' if true_label == 0 else 'Hallervorden-Spatz'})")

    try:
        # Generate response
        response = generate_response(image_path, prompt)
        print(f"Model Response: '{response}'")

        # Check if response is empty
        if not response or response.strip() == "":
            print("WARNING: Empty response from model!")
            predicted_label = 0  # Default to normal for empty responses
        else:
            # Classify the response
            predicted_label = classify_response(response)

        print(f"Predicted Label: {predicted_label} ({'Normal' if predicted_label == 0 else 'Hallervorden-Spatz'})")

        # Store results
        predictions.append(predicted_label)
        ground_truth.append(true_label)
        filenames.append(filename)

        # Show if correct
        correct = "✓" if predicted_label == true_label else "✗"
        print(f"Result: {correct}")

    except Exception as e:
        print(f"Error processing {filename}: {str(e)}")
        import traceback
        traceback.print_exc()

    print("-" * 70)

# Calculate accuracy and additional metrics
if len(predictions) > 0:
    correct_predictions = sum(1 for pred, true in zip(predictions, ground_truth) if pred == true)
    accuracy = correct_predictions / len(predictions)

    # Calculate confusion matrix components
    true_positives = sum(1 for pred, true in zip(predictions, ground_truth) if pred == 1 and true == 1)
    true_negatives = sum(1 for pred, true in zip(predictions, ground_truth) if pred == 0 and true == 0)
    false_positives = sum(1 for pred, true in zip(predictions, ground_truth) if pred == 1 and true == 0)
    false_negatives = sum(1 for pred, true in zip(predictions, ground_truth) if pred == 0 and true == 1)

    # Calculate metrics
    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0.0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0.0
    specificity = true_negatives / (true_negatives + false_positives) if (true_negatives + false_positives) > 0 else 0.0

    print(f"\n=== ACCURACY RESULTS ===")
    print(f"Total samples processed: {len(predictions)}")
    print(f"Correct predictions: {correct_predictions}")
    print(f"Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")

    print(f"\n=== CONFUSION MATRIX ===")
    print(f"True Positives (HS predicted as HS): {true_positives}")
    print(f"True Negatives (Normal predicted as Normal): {true_negatives}")
    print(f"False Positives (Normal predicted as HS): {false_positives}")
    print(f"False Negatives (HS predicted as Normal): {false_negatives}")

    print(f"\n=== PERFORMANCE METRICS ===")
    print(f"Precision: {precision:.4f} ({precision*100:.2f}%)")
    print(f"  - Proportion of true positive predictions among all positive predictions")
    print(f"  - Important for minimizing false alarms")
    print(f"Recall (Sensitivity): {recall:.4f} ({recall*100:.2f}%)")
    print(f"  - Proportion of true positive predictions among all actual positive instances")
    print(f"  - Crucial for identifying actual cases of Hallervorden-Spatz disease")
    print(f"Specificity: {specificity:.4f} ({specificity*100:.2f}%)")
    print(f"  - Proportion of true negative predictions among all actual negative instances")
    print(f"  - Important for correctly identifying normal/healthy cases")

    # Detailed breakdown
    normal_correct = true_negatives
    hs_correct = true_positives
    normal_total = true_negatives + false_positives
    hs_total = true_positives + false_negatives

    print(f"\n=== DETAILED RESULTS BY CLASS ===")
    normal_pct = f"{normal_correct/normal_total*100:.1f}%" if normal_total > 0 else "N/A"
    hs_pct = f"{hs_correct/hs_total*100:.1f}%" if hs_total > 0 else "N/A"
    print(f"Normal cases: {normal_correct}/{normal_total} correct ({normal_pct})")
    print(f"Hallervorden-Spatz cases: {hs_correct}/{hs_total} correct ({hs_pct})")

    # Additional derived metrics
    if precision > 0 and recall > 0:
        f1_score = 2 * (precision * recall) / (precision + recall)
        print(f"\nF1-Score: {f1_score:.4f} ({f1_score*100:.2f}%)")
        print(f"  - Harmonic mean of precision and recall")

    # Show misclassified cases
    print(f"\n=== MISCLASSIFIED CASES ===")
    misclassified_count = 0
    for filename, pred, true in zip(filenames, predictions, ground_truth):
        if pred != true:
            misclassified_count += 1
            pred_label = 'Normal' if pred == 0 else 'Hallervorden-Spatz'
            true_label = 'Normal' if true == 0 else 'Hallervorden-Spatz'
            error_type = ""
            if pred == 1 and true == 0:
                error_type = " (False Positive)"
            elif pred == 0 and true == 1:
                error_type = " (False Negative)"
            print(f"  {filename}: Predicted {pred_label}, Actual {true_label}{error_type}")

    if misclassified_count == 0:
        print("  No misclassified cases - Perfect classification!")

    # Summary for quick reference
    print(f"\n=== QUICK SUMMARY ===")
    print(f"Accuracy: {accuracy*100:.1f}% | Precision: {precision*100:.1f}% | Recall: {recall*100:.1f}% | Specificity: {specificity*100:.1f}%")

else:
    print("No predictions were made successfully.")

# %%
# @title Default title text
import os
import pandas as pd
from PIL import Image
import torch

# Set the test folder path and CSV paths
test_folder = "/content/drive/MyDrive/preprocessed_pneumothorax/test"
csv_path = "/content/drive/MyDrive/preprocessed_pneumothorax/test.csv"
metadata_csv_path = "/content/drive/MyDrive/preprocessed_pneumothorax/pneumothorax_combined.csv"

# Load the metadata CSV and prepare a lookup dictionary
background_df = pd.read_csv(metadata_csv_path)
background_lookup = background_df.set_index("Image Index")[["Follow-up #", "Patient Age", "Patient Sex"]].to_dict(orient="index")

# Load ground truth labels
df = pd.read_csv(csv_path)
filename_to_label = dict(zip(df.iloc[:, 0], df.iloc[:, 1]))
print(f"Loaded {len(df)} test samples from CSV")

# Make sure you have the right template
from llava.conversation import conv_templates, SeparatorStyle

def generate_response(image_path, metadata=None):
    print(f"  Loading image: {image_path}")

    image = Image.open(image_path).convert('RGB')
    print(f"  Image size: {image.size}")

    # Process image correctly
    image_tensor = image_processor.preprocess(image, return_tensors='pt')['pixel_values']
    image_tensor = image_tensor.to(model.device, dtype=torch.float16)
    print(f"  Image tensor shape: {image_tensor.shape}")

    # Use your original working prompt structure
    if metadata:
        prompt = f"This chest X-ray is from a {metadata['Patient Age']}-year-old {metadata['Patient Sex']} patient. Does this X-ray show pneumothorax? Answer Yes or No and explain briefly."
    else:
        prompt = "Does this chest X-ray show pneumothorax? Answer Yes or No and explain briefly."

    # Use the correct conversation template (NO SYSTEM PROMPT)
    conv = conv_templates["mistral_instruct"].copy()
    conv.append_message(conv.roles[0], f"\n{prompt}")
    conv.append_message(conv.roles[1], None)

    prompt_formatted = conv.get_prompt()
    print(f"  Formatted prompt length: {len(prompt_formatted)}")

    # Tokenize
    input_ids = tokenizer_image_token(
        prompt_formatted,
        tokenizer,
        IMAGE_TOKEN_INDEX,
        return_tensors='pt'
    ).unsqueeze(0).to(model.device)

    print(f"  Input IDs shape: {input_ids.shape}")
    print("  Generating response...")

    # Generate with your original working parameters
    with torch.inference_mode():
        output_ids = model.generate(
            input_ids,
            images=image_tensor,
            do_sample=True,
            temperature=0.7,  # Back to your original value
            top_p=0.9,
            max_new_tokens=128,  # Back to your original value
            use_cache=True,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id,
        )

    print(f"  Output IDs shape: {output_ids.shape}")
    print(f"  Input length: {input_ids.shape[1]}, Output length: {output_ids.shape[1]}")

    # Simple approach: get the new tokens
    response = tokenizer.decode(
        output_ids[0, input_ids.shape[1]:],
        skip_special_tokens=True
    ).strip()

    # Debug: also show full response
    full_response = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    print(f"  Full decoded response:\n{full_response}")
    print(f"  Extracted response: '{response}'")

    # If response is empty, try to extract from full response
    if not response and full_response:
        print("  Response empty, trying to extract from full response...")
        # Look for Yes/No patterns in full response
        full_clean = full_response.strip()
        if "Yes," in full_clean or "No," in full_clean:
            # Find the sentence that starts with Yes/No
            sentences = full_clean.split('.')
            for sentence in sentences:
                if sentence.strip().startswith(('Yes', 'No')):
                    response = sentence.strip() + "."
                    print(f"  Found Yes/No sentence: '{response}'")
                    break

    return response


def classify_response(response):
    """
    Classify response as pneumothorax (1) or no finding (0)
    """
    if not response or not response.strip():
        print("    Empty response - defaulting to No Finding")
        return 0

    response_lower = response.lower().strip()
    print(f"    Classifying: '{response[:100]}...'")

    # Check for explicit Yes/No at the start
    if response_lower.startswith("yes"):
        print(f"    Found 'Yes' at start -> Pneumothorax")
        return 1
    elif response_lower.startswith("no"):
        print(f"    Found 'No' at start -> No Finding")
        return 0

    # Check for pneumothorax keywords if no clear Yes/No
    pneumothorax_indicators = [
        "pneumothorax is present",
        "shows pneumothorax",
        "pneumothorax visible",
        "consistent with pneumothorax",
        "indicative of pneumothorax",
        "evidence of pneumothorax",
        "pneumothorax can be seen"
    ]

    negative_indicators = [
        "no pneumothorax",
        "does not show pneumothorax",
        "not indicate pneumothorax",
        "no evidence of pneumothorax",
        "no signs of pneumothorax",
        "normal chest x-ray",
        "appears normal"
    ]

    # Check for negative indicators first (they're often more explicit)
    for indicator in negative_indicators:
        if indicator in response_lower:
            print(f"    Found negative indicator: '{indicator}' -> No Finding")
            return 0

    # Check for positive indicators
    for indicator in pneumothorax_indicators:
        if indicator in response_lower:
            print(f"    Found positive indicator: '{indicator}' -> Pneumothorax")
            return 1

    # If contains "pneumothorax" but no clear positive/negative context
    if "pneumothorax" in response_lower:
        print(f"    Contains 'pneumothorax' but unclear context -> defaulting to No Finding")
        return 0  # Changed from 1 to 0 for safety

    print(f"    No clear indicators found -> defaulting to No Finding")
    return 0



predictions = []
ground_truth = []
filenames = []

print("\n=== Starting Inference Accuracy Test ===\n")

import random

# Convert dict items to list and shuffle the order
random.seed(42)  # or any number
shuffled_items = list(filename_to_label.items())
random.shuffle(shuffled_items)

for idx, (filename, true_label) in enumerate(shuffled_items):
    image_path = os.path.join(test_folder, filename)

    if not os.path.exists(image_path):
        print(f"Warning: Image {filename} not found, skipping...")
        continue

    metadata = background_lookup.get(filename)
    if not metadata:
        print(f"Warning: No metadata for {filename}, skipping...")
        continue

    print(f"[{idx+1}/{len(filename_to_label)}] Processing: {filename}")
    print(f"Ground Truth: {true_label} ({'No Finding' if true_label == 0 else 'Pneumothorax'})")

    try:
        response = generate_response(image_path, metadata)
        print(f"Model Response: '{response}'")

        if not response.strip():
            print("WARNING: Empty response from model!")
            predicted_label = 0
        else:
            predicted_label = classify_response(response)

        print(f"Predicted Label: {predicted_label} ({'No Finding' if predicted_label == 0 else 'Pneumothorax'})")
        predictions.append(predicted_label)
        ground_truth.append(true_label)
        filenames.append(filename)

        correct = "✓" if predicted_label == true_label else "✗"
        print(f"Result: {correct}")

    except Exception as e:
        print(f"Error processing {filename}: {str(e)}")
        import traceback
        traceback.print_exc()

    print("-" * 70)

# Metrics calculation
if predictions:
    correct_predictions = sum(p == t for p, t in zip(predictions, ground_truth))
    accuracy = correct_predictions / len(predictions)

    tp = sum(p == t == 1 for p, t in zip(predictions, ground_truth))
    tn = sum(p == t == 0 for p, t in zip(predictions, ground_truth))
    fp = sum(p == 1 and t == 0 for p, t in zip(predictions, ground_truth))
    fn = sum(p == 0 and t == 1 for p, t in zip(predictions, ground_truth))

    precision = tp / (tp + fp) if (tp + fp) else 0
    recall = tp / (tp + fn) if (tp + fn) else 0
    specificity = tn / (tn + fp) if (tn + fp) else 0

    print(f"\n=== ACCURACY RESULTS ===")
    print(f"Total samples processed: {len(predictions)}")
    print(f"Correct predictions: {correct_predictions}")
    print(f"Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")

    print(f"\n=== CONFUSION MATRIX ===")
    print(f"TP (Pneumothorax → Pneumothorax): {tp}")
    print(f"TN (No Finding → No Finding): {tn}")
    print(f"FP (No Finding → Pneumothorax): {fp}")
    print(f"FN (Pneumothorax → No Finding): {fn}")

    print(f"\n=== METRICS ===")
    print(f"Precision: {precision:.4f} ({precision*100:.2f}%)")
    print(f"Recall: {recall:.4f} ({recall*100:.2f}%)")
    print(f"Specificity: {specificity:.4f} ({specificity*100:.2f}%)")

    if precision > 0 and recall > 0:
        f1 = 2 * (precision * recall) / (precision + recall)
        print(f"F1-Score: {f1:.4f} ({f1*100:.2f}%)")

    print(f"\n=== MISCLASSIFIED CASES ===")
    misclassified = 0
    for fn, pred, true in zip(filenames, predictions, ground_truth):
        if pred != true:
            misclassified += 1
            pred_label = 'Normal' if pred == 0 else 'Pneumothorax'
            true_label = 'Normal' if true == 0 else 'Pneumothorax'
            print(f"  {fn}: Predicted {pred_label}, Actual {true_label}")
    if misclassified == 0:
        print("  No misclassifications – perfect result!")

    print(f"\n=== SUMMARY ===")
    print(f"Accuracy: {accuracy*100:.1f}%, Precision: {precision*100:.1f}%, Recall: {recall*100:.1f}%, Specificity: {specificity*100:.1f}%")

else:
    print("No successful predictions were made.")

# %%
import os
import pandas as pd
import torch
from PIL import Image
from llava.conversation import conv_templates
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import random

# Paths
test_folder = "/content/drive/MyDrive/preprocessed_pneumothorax/test"
csv_path = "/content/drive/MyDrive/preprocessed_pneumothorax/test.csv"
metadata_csv_path = "/content/drive/MyDrive/preprocessed_pneumothorax/pneumothorax_combined.csv"

# Load labels and metadata
df = pd.read_csv(csv_path)
filename_to_label = dict(zip(df.iloc[:, 0], df.iloc[:, 1]))
background_df = pd.read_csv(metadata_csv_path)
background_lookup = background_df.set_index("Image Index")[["Follow-up #", "Patient Age", "Patient Sex"]].to_dict(orient="index")

# Inference helper
def generate_response(image_path, metadata=None):
    image = Image.open(image_path).convert('RGB')
    image_tensor = image_processor.preprocess(image, return_tensors='pt')['pixel_values'].to(model.device, dtype=torch.float16)

    prompt = (
        f"You are an expert radiologist. This chest X-ray is from a {metadata['Patient Age']}-year-old (Sex: {metadata['Patient Sex']}) patient. "
        f"Does this chest X-ray show a pneumothorax? Answer 'Yes' or 'No' and provide an explanation"
        if metadata else
        "Does this chest X-ray show a pneumothorax? Answer 'Yes' or 'No' and provide an explanation"
    )

    conv = conv_templates["mistral_instruct"].copy()
    conv.append_message(conv.roles[0], f"\n{prompt}")
    conv.append_message(conv.roles[1], None)
    prompt_formatted = conv.get_prompt()

    input_ids = tokenizer_image_token(prompt_formatted, tokenizer, IMAGE_TOKEN_INDEX, return_tensors='pt').unsqueeze(0).to(model.device)

    with torch.inference_mode():
        output_ids = model.generate(
            input_ids,
            images=image_tensor,
            do_sample=True,
            temperature=0.5,
            top_p=0.9,
            max_new_tokens=256,
            use_cache=True,
            repetition_penalty=1.1,
            pad_token_id=tokenizer.eos_token_id,
        )

    full_decoded = tokenizer.decode(output_ids[0], skip_special_tokens=True).strip()
    response = full_decoded.split("### Assistant:")[-1].strip() if "### Assistant:" in full_decoded else full_decoded
    return response

# Evaluation tracking
true_labels = []
predicted_labels = []

# Shuffle dataset
shuffled_items = list(filename_to_label.items())
random.seed(42)
random.shuffle(shuffled_items)

# Process each image
for i, (filename, label) in enumerate(shuffled_items):
    image_path = os.path.join(test_folder, filename)
    if not os.path.exists(image_path):
        continue

    metadata = background_lookup.get(filename)
    response = generate_response(image_path, metadata)

    # Determine predicted label from response
    predicted_label = int(response.strip().lower().startswith("yes"))

    # Record prediction and ground truth
    true_labels.append(int(label))
    predicted_labels.append(predicted_label)

    print(f"Filename       : {filename}")
    print(f"Ground Truth   : {'Pneumothorax' if label == 1 else 'No Finding'}")
    print(f"Model Response : {response}")
    print("-" * 60)

    # Print metrics every 10 samples
    if (i + 1) % 10 == 0:
        tn, fp, fn, tp = confusion_matrix(true_labels, predicted_labels, labels=[0, 1]).ravel()
        acc = accuracy_score(true_labels, predicted_labels)
        prec = precision_score(true_labels, predicted_labels, zero_division=0)
        rec = recall_score(true_labels, predicted_labels, zero_division=0)
        f1 = f1_score(true_labels, predicted_labels, zero_division=0)
        spec = tn / (tn + fp) if (tn + fp) > 0 else 0.0

        print(f"After {i+1} samples:")
        print(f"  Accuracy   : {acc:.4f}")
        print(f"  Precision  : {prec:.4f}")
        print(f"  Recall     : {rec:.4f}")
        print(f"  Specificity: {spec:.4f}")
        print(f"  F1 Score   : {f1:.4f}")
        print("=" * 60)
# Out:
# Filename       : 00008304_001.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient was admitted with a right-sided pneumothorax, as seen on the chest X-ray.
# ------------------------------------------------------------
# Filename       : 00017972_046.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00015892_003.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the X-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00004581_006.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The image would likely show a thin line representing the edge of the collapsed lung, as well as the presence of air in the pleural space.
# ------------------------------------------------------------
# Filename       : 00022651_016.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000484_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00022707_013.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00020318_008.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the absence of a pneumothorax suggests that there is no evidence of air accumulation in the pleural space, and the lungs appear to be functioning normally.
# ------------------------------------------------------------
# Filename       : 00000652_018.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000426_003.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# After 10 samples:
#   Accuracy   : 0.5000
#   Precision  : 0.7500
#   Recall     : 0.4286
#   Specificity: 0.6667
#   F1 Score   : 0.5455
# ============================================================
# Filename       : 00010936_018.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The presence of a pneumothorax can be seen as a sharp line representing the edge of the collapsed lung on the chest X-ray.
# ------------------------------------------------------------
# Filename       : 00028861_013.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the pneumothorax is present on the right side of the patient's chest.
# ------------------------------------------------------------
# Filename       : 00005520_007.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00023283_016.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. Pneumothorax can be caused by various factors, such as trauma, lung disease, or spontaneous rupture of a weakened area in the lung.
# ------------------------------------------------------------
# Filename       : 00000273_005.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000450_004.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000248_025.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. Pneumothorax can be caused by various factors, such as trauma, lung disease, or spontaneous rupture of air-filled sacs (blebs) in the lung tissue.
# ------------------------------------------------------------
# Filename       : 00021770_014.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, meaning that there is no evidence of a pneumothorax or any other abnormalities in the image.
# ------------------------------------------------------------
# Filename       : 00028924_009.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient was admitted for a right pneumothorax, which means that the air accumulation is on the right side of the chest.
# ------------------------------------------------------------
# Filename       : 00000238_001.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# After 20 samples:
#   Accuracy   : 0.4500
#   Precision  : 0.5833
#   Recall     : 0.5385
#   Specificity: 0.2857
#   F1 Score   : 0.5600
# ============================================================
# Filename       : 00015244_000.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000545_008.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient has developed a right-sided pneumothorax after a medical procedure.
# ------------------------------------------------------------
# Filename       : 00000332_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00008465_004.png
# Ground Truth   : Pneumothorax
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000796_006.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00012094_020.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00008970_002.png
# Ground Truth   : Pneumothorax
# Model Response : The chest x-ray does not show a pneumothorax. it appears to be normal.
# ------------------------------------------------------------
# Filename       : 00000973_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00028640_004.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a left-sided pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00028765_004.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a left pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# After 30 samples:
#   Accuracy   : 0.4333
#   Precision  : 0.5556
#   Recall     : 0.5263
#   Specificity: 0.2727
#   F1 Score   : 0.5405
# ============================================================
# Filename       : 00000520_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00000762_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000689_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000438_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000168_000.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000583_017.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. Pneumothorax can be caused by various factors, such as trauma, lung disease, or spontaneous rupture of air-filled sacs (blebs) in the lung tissue.
# ------------------------------------------------------------
# Filename       : 00017634_006.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The presence of a pneumothorax in the chest X-ray may indicate an underlying issue that requires further evaluation and treatment.
# ------------------------------------------------------------
# Filename       : 00004517_005.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000506_030.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00014393_003.png
# Ground Truth   : Pneumothorax
# Model Response : No, the chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# After 40 samples:
#   Accuracy   : 0.4500
#   Precision  : 0.5000
#   Recall     : 0.5455
#   Specificity: 0.3333
#   F1 Score   : 0.5217
# ============================================================
# Filename       : 00000143_010.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00012020_011.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the pneumothorax is located on the right side of the patient's chest.
# ------------------------------------------------------------
# Filename       : 00000627_008.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax. it is important to note that the image is from a patient who underwent a thoracotomy, which is a surgical procedure involving opening the chest cavity.
# ------------------------------------------------------------
# Filename       : 00000929_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00003669_005.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000370_005.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The presence of a pneumothorax in the chest X-ray indicates that there is air in the pleural space, leading to a collapsed lung.
# ------------------------------------------------------------
# Filename       : 00028698_002.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000468_021.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax. it is important to note that the absence of a pneumothorax in this image does not necessarily rule out other potential lung abnormalities or conditions. further evaluation and clinical correlation may be needed to assess the patient's overall health and identify any underlying issues.
# ------------------------------------------------------------
# Filename       : 00018055_010.png
# Ground Truth   : Pneumothorax
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00029437_005.png
# Ground Truth   : Pneumothorax
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# After 50 samples:
#   Accuracy   : 0.5000
#   Precision  : 0.5357
#   Recall     : 0.5556
#   Specificity: 0.4348
#   F1 Score   : 0.5455
# ============================================================
# Filename       : 00005539_001.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. Pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the X-ray appears normal, without any signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00000468_051.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray shows a pneumothorax. a pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. this can cause the lung to collapse partially or completely. it is important to identify and treat pneumothoraxes promptly, as they can lead to complications if left untreated.
# ------------------------------------------------------------
# Filename       : 00000984_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The image would likely show an area of decreased density or increased radiolucency (brightness) on one side of the chest, indicating the presence of air in the pleural space.
# ------------------------------------------------------------
# Filename       : 00000784_000.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00019124_028.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the image does not reveal any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000398_007.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray shows a pneumothorax, which is a condition where air accumulates in the pleural space, causing the lung to collapse.
# ------------------------------------------------------------
# Filename       : 00028876_013.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient was admitted to the emergency department with a right-sided pneumothorax.
# ------------------------------------------------------------
# Filename       : 00028861_010.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray shows a pneumothorax, which is a condition where air accumulates in the pleural space, causing the lung to collapse.
# ------------------------------------------------------------
# Filename       : 00009889_034.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000121_003.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# After 60 samples:
#   Accuracy   : 0.5000
#   Precision  : 0.5312
#   Recall     : 0.5312
#   Specificity: 0.4643
#   F1 Score   : 0.5312
# ============================================================
# Filename       : 00000527_000.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax. a pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. in this case, the chest x-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00030753_000.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000870_006.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000857_003.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, meaning there are no visible signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00008566_018.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00015423_004.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the chest X-ray appears to be normal, meaning there is no visible evidence of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000505_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00012247_002.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000781_005.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000443_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the X-ray appears to be normal, meaning there is no evidence of a pneumothorax or any other significant abnormalities.
# ------------------------------------------------------------
# After 70 samples:
#   Accuracy   : 0.5286
#   Precision  : 0.5405
#   Recall     : 0.5556
#   Specificity: 0.5000
#   F1 Score   : 0.5479
# ============================================================
# Filename       : 00000275_003.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient's chest X-ray reveals the presence of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00002649_005.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the image does not reveal any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000376_011.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00015171_006.png
# Ground Truth   : Pneumothorax
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000082_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00001996_011.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00000834_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, meaning that there are no visible signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00002201_001.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000662_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00013310_068.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# After 80 samples:
#   Accuracy   : 0.5500
#   Precision  : 0.5714
#   Recall     : 0.5714
#   Specificity: 0.5263
#   F1 Score   : 0.5714
# ============================================================
# Filename       : 00003527_005.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms. It's important for the medical team to closely monitor the patient's condition and provide appropriate treatment to manage their symptoms and address the underlying cause of the pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000292_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000711_002.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a left-sided pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000817_001.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00020286_009.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00026810_014.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, without any signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00000627_006.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000754_005.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The presence of a pneumothorax on the chest X-ray indicates that there is air in the pleural space, leading to the collapse of the lung.
# ------------------------------------------------------------
# Filename       : 00018366_044.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000737_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the X-ray reveals the presence of a pneumothorax in the patient's chest.
# ------------------------------------------------------------
# After 90 samples:
#   Accuracy   : 0.5111
#   Precision  : 0.5208
#   Recall     : 0.5435
#   Specificity: 0.4773
#   F1 Score   : 0.5319
# ============================================================
# Filename       : 00000812_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00015556_003.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. The arrow in the image likely points to the area of the pneumothorax.
# ------------------------------------------------------------
# Filename       : 00029903_011.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the pneumothorax is located on the right side of the patient's chest.
# ------------------------------------------------------------
# Filename       : 00004656_001.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000727_008.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000265_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the absence of a pneumothorax indicates that there is no such accumulation of air in the pleural space.
# ------------------------------------------------------------
# Filename       : 00013031_013.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient was referred for a chest tube placement due to the presence of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00003126_007.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00027213_051.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000494_007.png
# Ground Truth   : No Finding
# Model Response : No, the chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# After 100 samples:
#   Accuracy   : 0.5200
#   Precision  : 0.5370
#   Recall     : 0.5577
#   Specificity: 0.4792
#   F1 Score   : 0.5472
# ============================================================
# Filename       : 00000268_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. Pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the X-ray appears to be normal, meaning there are no visible signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00000872_005.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the X-ray appears to be normal, meaning there are no visible signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00000681_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00001583_013.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00015530_151.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a right pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other complications.
# ------------------------------------------------------------
# Filename       : 00008376_000.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000701_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00012326_004.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the chest X-ray appears to be normal, meaning there is no visible evidence of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000571_003.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient was admitted for the treatment of pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000820_018.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# After 110 samples:
#   Accuracy   : 0.5182
#   Precision  : 0.5254
#   Recall     : 0.5536
#   Specificity: 0.4815
#   F1 Score   : 0.5391
# ============================================================
# Filename       : 00000246_007.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00008663_000.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000391_009.png
# Ground Truth   : No Finding
# Model Response : No, the chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the image appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000977_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the image does not reveal any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000231_007.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00027547_002.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000747_001.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000193_010.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00025769_009.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00018865_031.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# After 120 samples:
#   Accuracy   : 0.5333
#   Precision  : 0.5312
#   Recall     : 0.5667
#   Specificity: 0.5000
#   F1 Score   : 0.5484
# ============================================================
# Filename       : 00000250_011.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms. It's important for the medical team to closely monitor the patient's condition and provide appropriate treatment to manage their symptoms and improve their lung function.
# ------------------------------------------------------------
# Filename       : 00018521_009.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ...
# ------------------------------------------------------------
# Filename       : 00000573_011.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# After 590 samples:
#   Accuracy   : 0.4881
#   Precision  : 0.5174
#   Recall     : 0.5240
#   Specificity: 0.4477
#   F1 Score   : 0.5206
# ============================================================
# Filename       : 00019478_001.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00028211_007.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient's chest X-ray reveals the presence of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000121_004.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00012233_005.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000335_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00008464_001.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00008008_033.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the patient was admitted with a left-sided pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000757_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse. In this case, the chest X-ray does not reveal any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000230_006.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00005539_009.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# After 600 samples:
#   Accuracy   : 0.4867
#   Precision  : 0.5171
#   Recall     : 0.5204
#   Specificity: 0.4484
#   F1 Score   : 0.5188
# ============================================================
# Filename       : 00030606_014.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00027304_000.png
# Ground Truth   : Pneumothorax
# Model Response : The chest x-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000334_001.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. In this case, the X-ray reveals the presence of a pneumothorax, as indicated by the arrows.
# ------------------------------------------------------------
# Filename       : 00000511_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000756_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00017110_003.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the image does not reveal any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00015646_039.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. It is important to identify and treat a pneumothorax promptly, as it can lead to serious complications if left untreated.
# ------------------------------------------------------------
# Filename       : 00000479_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. Pneumothorax can be caused by various factors, such as trauma, lung disease, or spontaneous rupture of air-filled sacs (blebs) in the lung tissue.
# ------------------------------------------------------------
# Filename       : 00019124_105.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00002090_003.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# After 610 samples:
#   Accuracy   : 0.4820
#   Precision  : 0.5138
#   Recall     : 0.5169
#   Specificity: 0.4421
#   F1 Score   : 0.5153
# ============================================================
# Filename       : 00000797_001.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00016587_082.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000511_001.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00021374_028.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000634_006.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000683_003.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. It's important to note that the severity of a pneumothorax can vary, and further evaluation by a healthcare professional is necessary to determine the appropriate treatment and management plan.
# ------------------------------------------------------------
# Filename       : 00000265_003.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely.
# ------------------------------------------------------------
# Filename       : 00000673_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000824_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse. In this case, the chest X-ray appears to be normal, meaning there are no signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# Filename       : 00013111_053.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears to be normal, without any signs of a pneumothorax or other abnormalities.
# ------------------------------------------------------------
# After 620 samples:
#   Accuracy   : 0.4839
#   Precision  : 0.5121
#   Recall     : 0.5152
#   Specificity: 0.4486
#   F1 Score   : 0.5137
# ============================================================
# Filename       : 00020933_002.png
# Ground Truth   : Pneumothorax
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely. Pneumothorax can be caused by various factors, such as trauma, lung disease, or spontaneous rupture of air-filled sacs (blebs) in the lung tissue.
# ------------------------------------------------------------
# Filename       : 00000481_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00028421_004.png
# Ground Truth   : Pneumothorax
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000699_001.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and chest pain.
# ------------------------------------------------------------
# Filename       : 00000268_002.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000682_000.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, causing the lung to collapse. In this case, the chest X-ray appears normal, without any signs of a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000644_001.png
# Ground Truth   : No Finding
# Model Response : The chest X-ray does not show a pneumothorax.
# ------------------------------------------------------------
# Filename       : 00000502_014.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000667_000.png
# Ground Truth   : No Finding
# Model Response : Yes, the chest X-ray shows a pneumothorax. A pneumothorax is a condition where air accumulates in the pleural space, which is the area between the lung and the chest wall. This can cause the lung to collapse partially or completely, leading to difficulty breathing and other symptoms.
# ------------------------------------------------------------
# Filename       : 00000843_000.png
# Ground Truth   : No Finding
# Model Response : The chest x-ray does not show a pneumothorax. it appears to be normal, with no signs of lung collapse or other abnormalities.
# ------------------------------------------------------------
# After 630 samples:
#   Accuracy   : 0.4857
#   Precision  : 0.5090
#   Recall     : 0.5152
#   Specificity: 0.4533
#   F1 Score   : 0.5120
# ============================================================
